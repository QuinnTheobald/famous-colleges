# %% [markdown]
# # Data Cleaning
#     Quinn Theobald
#     INFO 2950
#     Final Project

# %% [markdown]
# `First, let's load up the data set.`

# %%
import pandas
import numpy
import re

# %%
wikipeople = pandas.read_csv('wikipeople.csv')
wikipeople.head()
# Out:
#                   name birth_date  \
# 0         Alain Connes       1947
# 1        Aldous Huxley       1894
# 2  Arthur Schopenhauer       1788
# 3      Albert Einstein       1879
# 4     Alfred Korzybski       1879
#
#                                     occupation  \
# 0                                          NaN
# 1  | occupation = {{hlist|Writer|philosopher}}
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                                            education
# 0  ['École Normale Supérieure', 'Pierre and Marie...
# 1        ['Eton College', 'Balliol College, Oxford']
# 2                                                 []
# 3  ['ETH Zurich|Federal Polytechnic School', 'Zur...
# 4                ['Warsaw University of Technology']

# %% [markdown]
# To do list:
# * convert `birth_date` to type int
# * try to wrangle with `occupations`
# * eliminate `Batchelor of Arts`
# * make `name` the index

# %% [markdown]
# ## Initial Cleaning

# %% [markdown]
# #### Convert birth_date to type int

# %%
wikipeople['birth_date'] = wikipeople['birth_date'].astype('int64')
wikipeople.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-fed07618547a> in <module>
# ----> 1 wikipeople['birth_date'] = wikipeople['birth_date'].astype('int64')
#       2 wikipeople.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     705         # work around NumPy brokenness, #1987
#     706         if np.issubdtype(dtype.type, np.integer):
# --> 707             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     708
#     709         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '| birth_date  = Late 12th Century'

# %% [markdown]
# Ruh roh. There seems to still be non-numbers in the `birth_date` column.

# %%
def only_years(thing):
    if thing is numpy.nan:
        return ''
    if len(thing) > 4:
        return ''
    else:
        return thing

# %%
wikipeople['birth_date'] = [ only_years(date) for date in wikipeople['birth_date'] ]
wikipeople.head()
# Out:
#                   name birth_date  \
# 0         Alain Connes       1947
# 1        Aldous Huxley       1894
# 2  Arthur Schopenhauer       1788
# 3      Albert Einstein       1879
# 4     Alfred Korzybski       1879
#
#                                     occupation  \
# 0                                          NaN
# 1  | occupation = {{hlist|Writer|philosopher}}
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#                                            education
# 0  ['École Normale Supérieure', 'Pierre and Marie...
# 1        ['Eton College', 'Balliol College, Oxford']
# 2                                                 []
# 3  ['ETH Zurich|Federal Polytechnic School', 'Zur...
# 4                ['Warsaw University of Technology']

# %%
wikipeople['birth_date'] = wikipeople['birth_date'].astype('int64')
wikipeople.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-fed07618547a> in <module>
# ----> 1 wikipeople['birth_date'] = wikipeople['birth_date'].astype('int64')
#       2 wikipeople.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     705         # work around NumPy brokenness, #1987
#     706         if np.issubdtype(dtype.type, np.integer):
# --> 707             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     708
#     709         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def empty_to_zero(thing):
    if thing == '':
        return 0
    else:
        return thing

# %%
wikipeople['birth_date'] = [ empty_to_zero(date) for date in wikipeople['birth_date'] ]
wikipeople['birth_date'] = wikipeople['birth_date'].astype('int64')
wikipeople.dtypes['birth_date']
# Out:
# dtype('int64')

# %% [markdown]
# #### Education field
#     Now let's take a closer look at the education field.

# %%
interesting = []
count = 0
for school in wikipeople.education:
    count += 1
    if (count > 30000):
        break
    if school.find('|') > -1:
        interesting.append(school)
    elif school.find('achelor') > -1:
        # I decided to exclude the 'b' in 'bachelor' for in case the b is sometimes capitalized, sometimes not
        interesting.append(school)
    elif school.find('asters') > -1:
        interesting.append(school)
interesting
# Out:
# ["['ETH Zurich|Federal Polytechnic School', 'Zurich', 'University of Zurich']",
#  "['École Polytechnique|École Polytech', 'École des ponts ParisTech|École des Ponts']",
#  "['Malvern College', 'Tonbridge School', 'Eastbourne College', 'Trinity College, Cambridge', 'occultist', 'ceremonial magic', 'Thelema', 'Æon of Horus', 'Royal Leamington Spa', 'Warwickshire', 'Christian fundamentalism|fundamentalist Christian', 'Plymouth Brethren', 'Western esotericism', 'Trinity College, Cambridge|Trinity College', 'University of Cambridge', 'British intelligence agency', 'Hermetic Order of the Golden Dawn', 'Samuel Liddell MacGregor Mathers', 'Charles Henry Allan Bennett|Allan Bennett', 'Boleskine House', 'Loch Ness', 'Oscar Eckenstein', 'Hindu', 'Buddhist', 'Rose Edith Kelly', 'Cairo', 'Aiwass', 'The Book of the Law', 'True Will', 'Magick (Thelema)|magick', '1905 Kanchenjunga expedition|an unsuccessful attempt to climb Kanchenjunga', 'George Cecil Jones', 'A∴A∴', 'Ordo Templi Orientis', 'First World War', 'Abbey of Thelema', 'Cefalù', 'libertine', 'recreational drug', 'bisexual', 'individualist', 'social critic', 'Satanist', 'counterculture']",
#  '[\'Sherborne School\', \'University of Cambridge\', "King\'s College, Cambridge", \'Bachelor of Arts|BA\', \'Master of Arts|MA\', \'Princeton University\']',
#  "['Santa Monica College', 'University of Wisconsin–Superior', 'Bachelor of Arts|BA']",
#  "['University of Glasgow', 'Balliol College, Oxford|Balliol College', 'University of Oxford|Oxford']",
#  '[\'University of Westminster|Royal Polytechnic Institution\', "St Mary\'s Hospital Medical School", \'Imperial College London\']',
#  "['Victoria University of Manchester|University of Manchester', 'Trinity College, Cambridge']",
#  "['Jazz Age', 'Broadway theatre|Broadway']",
#  "['University of Tübingen|Eberhard Karl University of Tübingen', 'Julius Maximilian University of Würzburg', 'Humboldt University of Berlin|Friedrich Wilhelm University']",
#  '["West Monmouth School|Jones\' West Monmouth School", \'Cowbridge Grammar School\', \'Royal Academy of Dramatic Art\']',
#  "['I.M. Sechenov First Moscow State Medical University|First Moscow State Medical University']",
#  "['Moscow State University', 'Lebedev Physical Institute|FIAN']",
#  "['University of Delhi', 'B.A.|BA', 'University of Oxford', 'M.A.|MA', 'SOAS University of London', 'Master of Philosophy|MPhil']",
#  "['Humboldt University of Berlin|University of Berlin', 'Hochschule für die Wissenschaft des Judentums|Higher Institute for Jewish Studies', 'rabbi', 'Judaism|Jewish', 'Jewish mysticism', 'Jewish Theological Seminary of America', 'Jewish philosophy', 'civil rights movement']",
#  '["St John\'s College, Oxford|St John\'s College"]',
#  "['Georgetown University', 'Bachelor of Science|BS', 'University College, Oxford', 'Yale University', 'Juris Doctor|JD']",
#  "['University of Western Australia', 'Bachelor of Arts|BA', 'Bachelor of Laws|LLB', 'University College, Oxford', 'Bachelor of Arts|BA', 'Australian National University']",
#  "['McGill University', 'Mathematics', 'Doctor of Philosophy|Ph.D.']",
#  "['University of Paris|Sorbonne', 'Downside School']",
#  "['Waltrip High School', 'University of St. Thomas (Houston)|University of Saint Thomas', 'Yeshiva University']",
#  "['University of Wisconsin–Madison', 'Bachelor of Arts|B.A.']",
#  "['New York University', 'Bachelor of Fine Arts|BFA']",
#  "['Hamilton College (New York)|Hamilton College', 'Harvard University']",
#  "['Richmond upon Thames College|Twickenham College of Technology']",
#  "['University of Michigan', 'Massachusetts Institute of Technology|MIT']",
#  "['Braunschweig University of Technology|Collegium Carolinum', 'University of Göttingen', 'University of Helmstedt']",
#  "['Widener University|Pennsylvania Military College', 'American Academy of Dramatic Arts']",
#  "['Charles University in Prague|University of Prague', 'University of Vienna', 'Jagiellonian University']",
#  "['City College of New York|City University of New York, City College', 'Bachelor of Science|BS', 'George Washington University', 'Master of Business Administration|MBA']",
#  "['University of Cape Town', 'University of Minnesota Medical Center|University of Minnesota']",
#  "['Mount Holyoke College', 'Bachelor of Arts|BA', 'Yale University', 'Master of Fine Arts|MFA', 'Dragonslayer (1981 film)|Dragonslayer', 'Broadway theater|Broadway', 'musical theater|musical', 'Titanic (musical)|Titanic', 'Pittsburgh', 'Victoria Clarke', 'Sewickley, Pennsylvania|Sewickley', 'Mount Holyoke College', 'Yale School of Drama', 'Yale Repertory Theater', 'Tales from the Vienna Woods', 'Dragonslayer (1981 film)|Dragonslayer', 'Broadway theater|Broadway', 'Crocodile Dundee', 'Broadway theater|Broadway', 'Titanic (musical)|Titanic', 'ovarian cancer', 'Pittsburgh', 'University of Pittsburgh', 'Pittsburgh Musical Theater', 'Theatre in Pittsburgh|Pittsburgh theatre', 'Trafford Tanzi|Teaneck Tanzi: The Venus Flytrap', 'The Marriage of Figaro (play)|The Marriage of Figaro', 'Arms and the Man', 'Strange Interlude', 'Titanic (musical)|Titanic: A New Musical', 'Tales from the Vienna Woods', 'Dragonslayer (1981 film)|Dragonslayer', 'Crocodile Dundee', 'Kenny (1988 film)|Kenny', 'The Big Picture (1989 film)|The Big Picture', 'Penn &amp; Teller Get Killed', 'Blown Away (1994 film)|Blown Away', 'Joe the King', 'Never Again (2001 film)|Never Again', 'Northern Exposure', 'The Equalizer', 'Once a Hero', 'Moonlighting (TV series)|Moonlighting', 'Sex And The City', 'Law &amp; Order', 'Matlock (TV series)|Matlock', 'Mayflower Madam', 'Love, Lies and Murder', 'The Stepford Husbands']",
#  "['Woodrow Wilson High School (Beckley, West Virginia)|Woodrow Wilson High School', 'West Virginia University', 'The Catholic University of America']",
#  "['Harrow High School|Harrow County School for Boys', 'Selwyn College, Cambridge']",
#  "['Colgate University', 'Brown University', 'Bachelor of Arts|AB', 'Columbia University', 'Bachelor of Laws|LLB']",
#  "['Gustavus Adolphus College', 'University of Minnesota', 'Symbionese Liberation Army', 'Patty Hearst', 'File:Camilla Hall as a child.jpg|thumb|left|border|Camilla Hall as a child']",
#  "['Harvard University', 'Bachelor of Arts|BA', 'University of Chicago', 'PhD']",
#  "['Case Western Reserve University|Case Institute of Technology', 'California Institute of Technology']",
#  "['Providence College', 'Bachelor of Arts|BA']",
#  "['Princeton University', 'Bachelor of Arts|BA']",
#  "['Massachusetts Institute of Technology', 'Bachelor of Science|BS', 'Harvard University', 'Master of Business Administration|MBA']",
#  "['Dartmouth College', 'Bachelor of Arts|BA', 'Lincoln College, Oxford']",
#  '[\'Emerson College\', \'Rescue Me (U.S. TV series)|Rescue Me\', \'George Stacy\', \'Marc Webb\', \'The Amazing Spider-Man (2012 film)|The Amazing Spider-Man\', \'Ivan Reitman\', \'Draft Day\', "A Bug\'s Life", \'List of Ice Age characters#Diego|Diego\', "Ice Age (franchise)|\'\'Ice Age\'\' franchise", \'Sex &amp; Drugs &amp; Rock &amp; Roll (TV series)|Sex &amp; Drugs &amp; Rock &amp; Roll\', \'FX (TV channel)|FX\']',
#  "['Shippensburg University of Pennsylvania|Shippensburg State College']",
#  "['Los Angeles Harbor College', 'California State University, Long Beach', 'Bachelor of Arts|BA', 'University of Southern California', 'Master of Arts|MA']",
#  "['Leipzig University', 'Humboldt University of Berlin|University of Berlin', 'University of Vienna', 'PhD', 'Martin Luther University of Halle-Wittenberg|University of Halle', 'Dr. phil. hab.']",
#  "['University of Canterbury#History|Canterbury College', 'University of New Zealand', 'University of Cambridge']",
#  "['University of Idaho', 'chemical engineering', 'Food engineering|food engineer', 'doughnut', 'science fiction author|science-fiction author', 'Lensman', 'Skylark (series)|Skylark', 'space opera']",
#  "['École Normale Supérieure|École préparatoire']",
#  '["Queens\' College, Cambridge", \'Collège de Montaigu\', \'University of Paris|Paris\', \'University of Turin\']',
#  "['Scuola Normale Superiore di Pisa|Scuola Normale Superiore']",
#  "['University of Montpellier', 'Free University of Brussels (1834–1969)|Free University of Brussels']",
#  "['Harvard University', 'Bachelor of Arts|AB', 'Master of Arts|AM']",
#  "['University of Texas at Austin|University of Texas', 'City College of New York', 'Neighborhood Playhouse School of the Theatre']",
#  "['Hofstra University', 'Bachelor of Arts|BA', 'University of California, Los Angeles', 'Master of Fine Arts|MFA']",
#  "['Harvard University', 'Bachelor of Arts|AB']",
#  "['University of Pennsylvania', 'Bachelor of Arts|A.B.', 'Master of Arts|A.M.']",
#  "['Dwight School|Timothy Dwight School', 'New York University', 'New York University School of Law']",
#  "['Northampton Grammar School', 'Mill Hill School', 'University College, London|University College', 'Gonville and Caius College, Cambridge']",
#  "['Toledo Infantry Academy|Infantry Academy of Toledo']",
#  "['Potchefstroom University for Christian Higher Education|Potchefstroom University', 'Bachelor of Arts|BA', 'Bachelor of Laws|LLB']",
#  "['University of Westminster|Royal Polytechnic Institution', 'Royal College of Chemistry']",
#  "['University of Oslo|Royal Frederick University']",
#  "['Yale University', 'Bachelor of Arts|BA']",
#  "['Peabody High School (Pennsylvania)|Peabody High School', 'University of Pittsburgh']",
#  "['ETH Zurich|Swiss Federal Polytechnic', 'Humboldt University of Berlin|University of Berlin']",
#  "['Northwestern University', 'Bachelor of Science|BS', 'Master of Science|MS']",
#  "['Leipzig University', 'Martin Luther University of Halle-Wittenberg|University of Wittenberg']",
#  '["St Paul\'s School (London)|St Paul\'s School", \'Slade School of Art\']',
#  "['University of Paris', 'Bachelor of Arts|B.A.', 'Master of Arts|M.A.']",
#  "['Palacký University, Olomouc|University of Olomouc', 'University of Vienna']",
#  "['Ithaca College', 'Bachelor of Fine Arts|BFA']",
#  '[\'University of Maryland, College Park|University of Maryland\', "Bachelor\'s degree|BA", \'University of Michigan\', "Master\'s degree|MA", \'University of California, Berkeley\', \'Doctor of Philosophy|PhD\']',
#  "['Franklin High School (Los Angeles, California)|Franklin High School', 'Los Angeles City College']",
#  "['George Fox University', 'Stanford University', 'Bachelor of Science|BS']",
#  "['City College of New York|City University of New York, City College', 'Harvard University', 'Bachelor of Arts|AB', 'Master of Arts|AM', 'Doctor of Philosophy|PhD']",
#  "['California Institute of Technology|Caltech', 'Bachelor of Science|B.S.', 'University of Oslo', 'Harvard University|Harvard', 'Doctorate|Ph.D.']",
#  "['Randwick Public School', 'Nubba, New South Wales|Nubba State School', 'Abbotsholme College', 'Wesley College (Victoria)|Wesley College, Melbourne', 'University of Melbourne']",
#  "['Trinity School (New York City)|Trinity School', 'Phillips Academy']",
#  "['Harvard University', 'Bachelor of Arts|BA']",
#  "['Trinity College, Oxford|Trinity College', 'University of Oxford', 'Victoria University of Manchester|University of Manchester']",
#  "['Columbia University', 'Bachelor of Science', 'Master of Arts', 'Doctor of Philosophy']",
#  "['Collegium Fridericianum', 'University of Königsberg', 'Bachelor of Arts|B.A.', 'Master of Arts|M.A.', 'PhD']",
#  "['University of Pennsylvania', 'Massachusetts Institute of Technology', 'Bachelor of Architecture|BArch', 'Harvard University', 'Master of Architecture|MArch']",
#  "['Harvard University', 'Bachelor of Arts|BA', 'Master of Arts|MA']",
#  "['University of Wisconsin–Madison|University of Wisconsin', 'Princeton University']",
#  "['Phillips Academy|Phillips Academy Andover', 'Harvard College']",
#  "['Plympton Grammar School|Plympton Free Grammar School']",
#  "['University of New Hampshire', 'Bachelor of Arts|BA', 'Harvard University', 'Master of Business Administration|MBA', 'Georgetown University', 'Juris Doctor|JD']",
#  "['The College of William &amp; Mary|College of William and Mary']",
#  "['University of Saskatchewan', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Bachelor of Laws|LLB']",
#  "['DePauw University', 'Bachelor of Arts|BA', 'Indiana University – Purdue University Indianapolis|Indiana University, Indianapolis', 'Juris Doctor|JD']",
#  "['Eötvös Loránd University|Pázmány Péter University', 'ETH Zurich|ETH Zürich', 'University of Göttingen']",
#  "['Princeton University', 'Bachelor of Arts|BA']",
#  "['University of North Carolina at Chapel Hill|University of North Carolina, Chapel Hill', 'Bachelor of Arts|BA']",
#  "['Georgia Southwestern State University|Georgia Southwestern College', 'Georgia Institute of Technology', 'United States Naval Academy', 'Bachelor of Science|BS', 'Union College']",
#  "['Cornell University', 'Bachelor of Arts|BA', 'Yale University', 'Master of Fine Arts|MFA']",
#  "['University of Exeter', 'Bachelor of Arts|BA']",
#  "['Charles University in Prague|University of Prague']",
#  "['George Washington University', 'Bachelor of Laws|LLB', 'Master of Laws|LLM']",
#  "['Cornell University', 'Bachelor of Science|BS', 'Harvard University', 'Juris Doctor|JD']",
#  "['Transylvania University', 'United States Military Academy|U.S. Military Academy', 'Bachelor of Science|BS']",
#  "['Michigan State University', 'Bachelor of Science|BS', 'Western Michigan University Cooley Law School|Thomas M. Cooley Law School', 'Juris Doctor|JD']",
#  "['Collège Stanislas de Paris|Collège Stanislas', 'University of Paris', 'Specialist diploma|certificate of specialist', 'legal medicine', 'M.D.']",
#  "['Occidental College', 'Bachelor of Arts|BA']",
#  "['Washington &amp; Jefferson College|Washington and Jefferson College', 'Bachelor of Arts|BA']",
#  "['Princeton University', 'Bachelor of Arts|BA', 'Yale University', 'Juris Doctor|JD', 'Master of Divinity|MDiv', 'Attorney General of Missouri', 'United States Senator', 'United States Ambassador to the United Nations', 'Episcopal priest', 'William H. Danforth', 'Ralston Purina', 'William Henry Danforth', 'Washington University in St. Louis', 'Mary Institute and St. Louis Country Day School|St. Louis Country Day School', 'Princeton University', 'Davis Polk &amp; Wardwell', 'List of United States Senators from Missouri|U.S. Senators', 'List of Governors of Missouri|Governors', 'Thomas Hart Benton (senator)|Thomas Hart Benton', 'Harry S. Truman', 'File:Portrait of John C. Danforth.jpg|thumb|left|150px|Danforth as Attorney General, 1969', 'Missouri Attorney General', 'Kit Bond', 'John Ashcroft', 'Clarence Thomas', 'United States Senate', 'Stuart Symington', 'James W. Symington', 'Warren Hearnes', 'Jerry Litton', 'Chillicothe, Missouri', 'Jimmy Carter', 'Georgia (U.S. state)|Georgia']",
#  "['High School, Edinburgh|High School', 'Edinburgh University', 'Royal College of Physicians of Edinburgh']",
#  "['Columbia University', 'Bachelor of arts|BA', 'Master of arts|MA']",
#  "['Marquette University', 'Bachelor of Laws|LLB']",
#  "['École Normale Supérieure', 'University of Paris', 'Bachelor of Arts|B.A.', 'Master of Arts|M.A.']",
#  '[\'Brunswick, Maine\', \'Fair Haven, Connecticut\', \'Bowdoin College\', \'Andover Theological Seminary\', \'pedagogical\', \'Brunswick, Maine\', \'Jacob Abbott\', "Abbott\'s Institute", \'Bowdoin College\', \'Andover Theological Seminary\', \'Puritan|Congregational Church\', \'Worcester, Massachusetts|Worcester\', \'Roxbury, Massachusetts|Roxbury\', \'Nantucket, Massachusetts|Nantucket\', \'Massachusetts\', \'Napoleon Bonaparte\', \'American Civil War|Civil War\', \'Napoleon III\', \'Frederick the Great\', \'Daniel Boone\', \'Jacob Abbott\']',
#  "['American University', 'George Washington University|George Washington U.']",
#  "['University of Melbourne', 'Doctor of Medicine|MD', 'University of Oxford']",
#  "['Yale University', 'Bachelor of Arts|BA', 'University of Chicago', 'Juris Doctor|JD']",
#  "['Harvard University', 'McGill University', 'Bachelor of Arts|B.A.', 'Yale University', 'Master of Arts|M.A.', 'PhD']",
#  "['University College, Oxford', 'Lincoln College, University of Oxford|Lincoln College, Oxford']",
#  "['Georgetown University', 'Bachelor of Science|BS']",
#  "['Victoria University of Manchester|University of Manchester', 'London School of Hygiene &amp; Tropical Medicine']",
#  "['Illinois State University (Springfield, Illinois)|Illinois State University', 'Brown University', 'Bachelor of Arts|BA']",
#  "['University of Freiburg', 'Ludwig Maximilian University of Munich|University of Munich', 'University of Bonn']",
#  "['University of Texas at Austin|University of Texas, Austin']",
#  "['University of Bonn', 'Humboldt University of Berlin|University of Berlin', 'University of Jena']",
#  "['Northwestern University School of Law|Union College of Law', 'read law']",
#  "['Kwame Nkrumah University of Science and Technology|Kumasi College of Science and Technology', 'Macalester College', 'Graduate Institute of International and Development Studies', 'Massachusetts Institute of Technology']",
#  "['Charles University in Prague|Prague University']",
#  '[\'Lincoln University (Pennsylvania)|Lincoln University, Pennsylvania\', \'University of Pennsylvania\', \'London School of Economics\', \'University College London\', "City Law School|Gray\'s Inn"]',
#  "['Diplomatic Academy of Vienna|Vienna Consular Academy']",
#  "['Gordon College (Massachusetts)|Gordon College', 'University of Michigan']",
#  "['Glendale High School (Glendale, California)|Glendale High School']",
#  "['National Ballet School|National Ballet School of Canada']",
#  "['Southern Methodist University', 'Bachelor of Science|BS', 'University of Texas at Austin', 'Master of Science|MS']",
#  "['Berlin Institute of Technology|Technische Hochschule Berlin', 'diploma', 'Victoria University of Manchester', 'Trinity College, Cambridge']",
#  "['Séminaire de Sherbrooke|Séminaire Saint-Charles-Borromée', 'Université Laval']",
#  '[\'City College of New York\', "Bachelor\'s degree|B.A.", \'Columbia University\', \'Doctor of Philosophy|Ph.D.\']',
#  "['Friedrich-Alexander-University, Erlangen-Nuremberg|University of Erlangen-Nuremberg']",
#  "['Pembroke College, Cambridge|Pembroke Hall, Cambridge']",
#  "['Harvard College', 'University of Wisconsin–Madison|University of Wisconsin', 'University of Chicago', 'University of Leipzig', 'University of Göttingen']",
#  "['Manumit School', 'St. Leo University|St. Leo College Preparatory School']",
#  "['Lincoln High School (Portland, Oregon)|Lincoln High School', 'The Evergreen State College']",
#  "['New York University', 'Bachelor of Arts|BA', 'Master of Fine Arts|MFA']",
#  "['University College London', 'Bachelor of Laws|LL.B.', 'Inner Temple']",
#  "['University of Berlin|Friedrich Wilhelm University', 'Heidelberg University']",
#  "['Brasenose College, Oxford', 'Bachelor of Arts|B.A.']",
#  "['Rutgers University', 'Bachelor of Arts|BA', 'University of Chicago', 'Master of Arts|MA', 'Columbia University', 'PhD']",
#  "['Eötvös Loránd University', 'Karlsruhe Institute of Technology|Technische Hochschule', 'University of Budapest']",
#  '["Kesteven and Grantham Girls\' School|{{Longitem|Kesteven and Grantham Girls\'&amp;nbsp;School}}", \'Somerville College, Oxford\', \'Inns of Court School of Law\']',
#  "['Santa Monica College', 'Lewis &amp; Clark College|Lewis and Clark College', 'Bachelor of Science|BS', 'London School of Economics', 'Master of Science|MSc']",
#  "['Morehouse College', 'Bachelor of Arts|BA', 'Crozer Theological Seminary', 'Bachelor of Divinity|BDiv', 'Boston University', 'Doctor of Philosophy|PhD']",
#  "['Delft University of Technology|Technical College of Delft', 'Villa Welgelegen|Haarlem School of Architecture and Decorative Arts']",
#  "['University of Paris|Sorbonne']",
#  '[\'Kabul University\', "St. Joseph\'s School (Baramulla)|St. Joseph\'s School", \'Baramulla\', \'India\']',
#  "['Pennsylvania Academy of the Fine Arts', 'Jean-Léon Gérôme', 'Charles Joshua Chaplin|Charles Chaplin', 'Thomas Couture']",
#  "['Yale University', 'Bachelor of Science|B.Sc.', 'Massachusetts Institute of Technology', 'Doctor of Philosophy|Ph.D.']",
#  "['University of Kansas|University of Kansas, Lawrence', 'Juilliard School']",
#  "['Trinity College Dublin', 'City Law School|Inns of Court School of Law', 'Harvard University']",
#  "['Harvard College', 'Bachelor of Arts|AB', 'Harvard Medical School', 'Doctor of Medicine|MD']",
#  "['Haas School of Business|University of California, Berkeley', 'Wharton School of the University of Pennsylvania|University of Pennsylvania']",
#  "['Immaculate Heart High School (Los Angeles)|Immaculate Heart High School']",
#  "['Bradley University', 'Bachelor of Arts|B.A.', 'Southern Illinois University Carbondale', 'juris doctor|J.D.']",
#  "['Smith College', 'Bachelor of Arts|BA']",
#  "['University of Pennsylvania', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Doctor of Philosophy|PhD', 'Harvard Society of Fellows']",
#  "['University of Oslo|Royal Frederick University']",
#  "['Yale College|Yale University', 'New College, Oxford']",
#  "['Bachelor of Science|BS', 'Master of Science|MSc', 'Université Laval', 'University of California, Berkeley']",
#  "['Pembroke School, Adelaide|Pembroke School', 'University of Adelaide']",
#  "['Seichō-ji|Kiyozumi-dera']",
#  "['University of Göttingen', 'Humboldt University of Berlin|University of Berlin', 'University of Greifswald']",
#  "['The College at Brockport, State University of New York|State University of New York, Brockport', 'United States Naval Academy', 'Bachelor of Science|BS']",
#  "['University of Munich', 'Humboldt University of Berlin|University of Berlin', 'University of Halle']",
#  "['Rutgers University–New Brunswick|Rutgers University, New Brunswick', 'New York University', 'Columbia University', 'Bachelor of Laws|LLB', 'SOAS, University of London|University of London']",
#  "['Lakeside School (Seattle, Washington)|Lakeside School', 'Washington State University']",
#  "['Law', 'History', 'Philosophy', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Philosophy', 'BPhil', 'University of Melbourne', 'University College, Oxford']",
#  "['Hamilton College (New York)|Hamilton College', 'New School', 'Bachelor of Arts|BA', 'Syracuse University', 'Master of Public Administration|MPA']",
#  "['Goethe University Frankfurt|University of Frankfurt']",
#  "['LaSalle Catholic College, Bankstown|De La Salle Catholic College']",
#  "['Forman Christian College', 'Pakistan Military Academy', 'Command and Staff College', 'National Defence University, Pakistan|National Defence University', 'Royal College of Defence Studies|Royal College of Defence']",
#  "['Université de Montréal', 'Harvard University', 'Sciences Po', 'London School of Economics', 'Law', 'Doctor of Law|LL.B.', 'Political economy', 'M.A.']",
#  "['The College of William &amp; Mary|College of William and Mary']",
#  "['Sciences Po|Paris Institute of Political Studies']",
#  "['Marshall University', 'Bachelor of Arts|BA', 'American University', 'Juris Doctor|JD']",
#  "['Eureka College', 'Bachelor of Arts|BA']",
#  "['Massachusetts Institute of Technology', 'Bachelor of Science|S.B. 1939', 'Princeton University', 'Doctor of Philosophy|Ph.D. 1942']",
#  "['Prytanée National Militaire|Collège Royal Henry-Le-Grand', 'University of Poitiers', 'University of Faraz', 'Leiden University']",
#  "['St. Anthony Catholic School', 'St. Anthony Catholic High School (San Antonio, Texas)|St. Anthony Catholic High School', 'University of Texas at Austin College of Communication|College of Communication', 'University of Texas at Austin']",
#  "['Princeton University', 'Bachelor of Arts|BA', 'Harvard University', 'Bachelor of Laws|LLB']",
#  '["Queen\'s University at Kingston|Queen\'s University", \'Balliol College, Oxford\']',
#  "['Wesley College, Melbourne|Wesley College', 'University of Melbourne']",
#  "['University of California, Berkeley|UC Berkeley', 'Stanford University']",
#  "['Manhattan College', 'Bachelor of Arts|BA', 'New York University', 'Juris Doctor|JD']",
#  "['Worcester College, Oxford', 'Bachelor of Arts|BA']",
#  "['TU Wien|Vienna Institute of Technology', 'University of Rostock']",
#  "['University of Cambridge', 'Emmanuel College, Cambridge|Emmanuel College', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Clare College, Cambridge|Clare Hall', 'Bachelor of Divinity|BD', 'Doctor of Divinity|DD']",
#  "['Columbia University', 'Bachelor of Arts|AB', 'Princeton University', 'Doctor of Philosophy|PhD', 'Oxford University', 'Fulbright Program|Fulbright Scholar']",
#  "['Vassar College', 'Bachelor of Arts|BA', 'New School of Social Research', 'Columbia University', 'Doctor of Philosophy|PhD']",
#  "['Bronx High School of Science', 'Queens College, City University of New York|Queens College', 'Columbia University', 'Cornell University']",
#  "['University of Vienna', 'Doctor of medicine|MD']",
#  "['Saratoga High School (California)|Saratoga High School', 'California State University, Long Beach']",
#  "['Morehouse College', 'Bachelor of Arts|BA', 'New York University', 'Master of Fine Arts|MFA']",
#  "['Queens College, City University of New York|Queens College, New York', 'Harvard University']",
#  '[\'Huntingdon Grammar School\', "St Paul\'s School (London)|St Paul\'s School", \'Magdalene College, Cambridge\']',
#  "['Bachelor of Science|BS', 'University of California, Berkeley', 'Massachusetts Institute of Technology|MIT', 'Lemelson Foundation', 'University of California, Berkeley|UC Berkeley', 'De Anza College', 'University of Colorado Boulder', 'Homestead High School (Cupertino, California)|Homestead High School']",
#  "['École Polytechnique', 'École royale du génie de Mézières|École Royale du Génie', 'University of Paris', 'Collège de France']",
#  "['University of Chicago', 'Northwestern University', 'University of Wisconsin–Madison|University of Wisconsin']",
#  "['University of Engineering and Technology, Lahore|University of Engineering and Technology', 'University of Manchester']",
#  "['Lviv Polytechnic|Technical University of Lwów']",
#  "['Harvard University', 'Bachelor of Arts|BA', 'Stanford Graduate School of Business']",
#  '[\'Hertford College, Oxford|Magdalen Hall\', \'University of Oxford|Oxford\', "St John\'s College, Cambridge|St John\'s College", \'University of Cambridge|Cambridge\']',
#  "['College of William &amp; Mary|College of William and Mary', 'Bachelor of Arts|BA']",
#  '["The Queen\'s College, Oxford|Queen\'s College, Oxford"]',
#  "['Loyola University Maryland|Loyola College', 'Bachelor of Arts|BA']",
#  "['Harvard University|Harvard', 'Doctoral candidate|PhD (cand)', 'Harvard University', 'Merton College, Oxford']",
#  "['Harvard University', 'Bachelor of Arts|AB']",
#  "['South Dakota State University', 'Bachelor of Arts|BA']",
#  "['University of Alabama', 'Bachelor of Arts|BA', 'Washington State University', 'Master of Science|MS', 'University of California, Berkeley', 'Doctor of Philosophy|PhD']",
#  "['Wabash College', 'Bachelor of Arts|BA']",
#  "['Hamilton College', 'Bachelor of Arts|B.A.', 'Washington and Lee University', 'Juris Doctor|J.D.']",
#  "['Burbank High School (Burbank, California)|Burbank High School', 'California Institute of the Arts']",
#  "['University of Kentucky', 'Bachelor of Science|B.S.', 'Johns Hopkins University', 'Doctor of Philosophy|Ph.D.']",
#  "['United States Military Academy', 'Bachelor of Science|BS']",
#  "['Polytechnic University of Turin|Technical School for Engineers in Turin']",
#  "['Davidson College', 'Bachelor of Arts|BA', 'University of Arkansas', 'Juris Doctor|JD']",
#  "['Loreto Convent, Darjeeling|Loreto Convent', 'Woldingham School|Convent of the Sacred Heart', 'Royal Academy of Dramatic Art']",
#  "['Saint Petersburg State University', 'LLB', 'Saint Petersburg Mining Institute', 'Candidate of Sciences|PhD']",
#  "['Viadrina European University|University of Frankfurt (Oder)', 'University of Göttingen']",
#  "['McGill University', 'Bachelor of Civil Law|LL.L.']",
#  "['Yale University', 'Bachelor of Arts|BA', 'University of Cincinnati', 'Bachelor of Laws|LLB']",
#  "['Davidson College', 'Princeton University', 'Bachelor of Arts|AB', 'University of Virginia', 'Johns Hopkins University', 'Master of Arts|MA', 'Doctor of Philosophy|PhD']",
#  "['Harvard College|Harvard University']",
#  "['Nyenrode Business University', 'Bachelor of Public Administration|BPA']",
#  "['Harvard University', 'Bachelor of Arts|BA', 'Magdalen College, Oxford']",
#  "['NYU', 'Political Science', 'Master of Arts|M.A.', 'UCLA', 'Political Science', 'Bachelor of Arts|B.A.', 'Montclair State University', 'Social Sciences', 'NYU', 'UCLA', 'Montclair State University']",
#  "['Harvard University', 'Bachelor of Arts|AB', 'Master of Arts|AM', 'University of Cambridge']",
#  "['Indiana University Bloomington|Indiana University, Bloomington', 'Bachelor of Arts|BA', 'Bachelor of Laws|LLB']",
#  "['Howard University', 'Barnard College', 'Bachelor of Arts|BA']",
#  "['United States Military Academy|USMA', 'University of Michigan|UMich']",
#  "['Virginia Military Institute', 'Bachelor of Science|BS']",
#  "['King Edward VI High School for Girls|King Edward VI High School', 'UCL Medical School']",
#  '[\'Tak Sun Secondary School|Tak Sun\', \'La Salle College\', "St. Francis Xavier\'s College", \'Seattle Central College|Edison Technical School\', \'University of Washington\']',
#  "['Western Reserve University', 'Bachelor of Arts|B.A.', 'Columbia University', 'Master of Arts|M.A.']",
#  "['École normale supérieure (Paris)|École Normale Supérieure', 'Humboldt University of Berlin|Friedrich Wilhelms University', 'University of Leipzig', 'University of Marburg']",
#  "['Harvard University', 'Bachelor of Arts|AB']",
#  "['Northwestern University', 'Bachelor of Science|BS', 'Yale Law School|Yale University', 'Juris Doctor|JD', 'New York University School of Law|New York University', 'LLM']",
#  "['Johns Hopkins University', 'Bachelor of Science|BS', 'Harvard Business School', 'Master of Business Administration|MBA']",
#  "['Johns Hopkins University', 'Bachelor of Arts|BA', 'University of Baltimore', 'Bachelor of Laws|LLB']",
#  "['Uppsala University|University of Uppsala']",
#  '[\'female impersonator\', \'Bette Davis\', \'Watertown, New York\', \'tuxedo (clothing)|tuxedo\', \'drag queen\', \'San Francisco\', \'Hollywood\', \'female impersonator\', \'Mae West\', \'Tallulah Bankhead\', \'Gloria Swanson\', \'Carol Channing\', \'Katharine Hepburn\', \'Joan Crawford\', \'Canon (basic principle)|canon\', \'Imitation|mimicry\', \'Joan Collins\', \'Carol Channing\', \'celebrities\', \'Studio One Backlot\', \'Kirk Frederick\', \'Geraldine Fitzgerald\', \'Nightclub|clubs\', \'The Village Gate\', "Bimbo\'s 365 Club", \'Fairmont San Francisco#Popular culture|Venetian Room\', \'Fairmont San Francisco|Fairmont Hotel\', \'Louise M. Davies Symphony Hall\', \'War Memorial Opera House\', \'Wonder Woman (TV series)|Wonder Woman\', \'cross-dressing\', \'Laverne &amp; Shirley\', \'Dixie Carter\', \'sitcom\', \'Designing Women\', \'cruise ship\', \'North Hollywood, California\', \'Forest Lawn Memorial Park (Hollywood Hills)|Forest Lawn Memorial Park\', \'Bea Arthur\', \'Forest Lawn Memorial Park (Hollywood Hills)|Forest Lawn - Hollywood Hills Cemetery\', \'Los Angeles, California\', \'Bea Arthur\', \'Tony Award\', \'Broadway theatre|Broadway\', "London\'s West End"]',
#  "['University of Milan', 'Sapienza University of Rome|University of Rome']",
#  "['Leibniz University Hannover|Hannover Polytechnic', 'Kunstakademie Düsseldorf', 'Royal Academy of Fine Arts (Antwerp)|Beaux-Arts Academy, Antwerp', 'Academy of Fine Arts, Munich']",
#  "['Christ Church, Oxford|Christ Church', 'Oxford University|Oxford']",
#  "['DePaul University', 'Bachelor of Laws|LLB', 'Mayor of Chicago', 'Cook County Democratic Party', 'Irish American', 'Bridgeport, Chicago|Bridgeport', 'Daley family', 'Richard M. Daley', 'William M. Daley', 'United States Secretary of Commerce', 'John P. Daley', 'Cook County Board of Commissioners', 'Patrick Daley Thompson', 'Chicago City Council', 'rust belt', 'Cleveland', 'Buffalo, New York|Buffalo', 'Detroit', 'Irish Catholic', 'Lyndon B. Johnson', 'Kennedy family', 'history of the United States Democratic Party', 'John F. Kennedy', '1960 United States presidential election|1960', 'Hubert Humphrey', '1968 United States presidential election|1968', 'Martin Luther King Jr.', '1968 Democratic National Convention', 'political corruption|corruption']",
#  "['Providence College', 'DePaul University', 'Bachelor of Arts|BA', 'Juris Doctor|JD']",
#  "['St. Mary of the Woods College|St. Mary of the Woods', 'Barat College', 'Bachelor of Science|BS']",
#  "['Roosevelt University', 'Bachelor of Arts|BA', 'Northwestern University', 'Juris Doctor|JD']",
#  "['Hiram College', 'Williams College', 'Bachelor of Arts|BA']",
#  "['Jesuit', 'Lyceum', 'diploma', 'Baron', 'Slovenes|Slovene', 'mathematician', 'physicist', 'artillery', 'Commissioned officer|officer']",
#  '["Columbia College (New York)|King\'s College", \'Founding Fathers of the United States\', \'U.S. Constitution\', \'Federalist Party\', \'United States Coast Guard\', \'New York Post\', \'Secretary of the Treasury\', \'George Washington\', \'First Bank of the United States|national bank\', \'Charlestown, Saint Kitts and Nevis|Charlestown\', \'Nevis\', \'American Revolutionary War\', \'Continental Army\', \'Congress of the Confederation\', \'Bank of New York\', \'Articles of Confederation\', \'Annapolis Convention (1786)|Annapolis Convention of 1786\', \'Constitutional Convention (United States)|Constitutional Convention\', \'Philadelphia\', \'The Federalist Papers\', \'Constitutional interpretation\', \'United States Department of the Treasury|Treasury Department\', \'implied powers\', \'National debt of the United States|national debt\', \'tariff\', \'whiskey tax\', \'French Revolution|French revolutionaries\', \'Democratic-Republican Party (United States)|Democratic-Republican Party\', \'Thomas Jefferson\', \'James Madison\', \'French First Republic\', \'John Adams\', \'Commanding General of the United States Army|Commanding General\', \'Quasi-War\', \'1800 United States presidential election|1800\', \'Aaron Burr\', \'United States electoral college|electoral college\', \'Burr–Hamilton duel|a duel\']',
#  "['Illinois College', 'Bachelor of Arts|BA', 'Northwestern University', 'Bachelor of Laws|LLB']",
#  "['Lviv Polytechnic#Second Polish Republic|Lwów Polytechnic Institute', 'Second Polish Republic']",
#  "['Goethe University Frankfurt', 'PhD|Ph.D.']",
#  "['École normale supérieure (Paris)|École Normale Supérieure']",
#  '["St. Peter\'s Boys School", \'West Thames College|Isleworth Polytechnic College\', \'Ealing Art College\']',
#  "['Hampton School|Hampton Grammar School', 'Imperial College London']",
#  '["Bachelor\'s degree", \'Doctor of Philosophy|Ph.D\']',
#  "['Leiden University|University of Leiden', 'University of Angers']",
#  "['Macalester College', 'University of Minnesota', 'Bachelor of Arts|BA', 'Juris Doctor|JD']",
#  "['Eötvös Loránd University|University of Budapest']",
#  "['DePaul University', 'Bachelor of Fine Arts|BFA']",
#  "['Industrial Academy (Moscow)|Industrial Academy']",
#  "['University of Minnesota', 'Bachelor of Arts|BA', 'Louisiana State University', 'Master of Arts|MA']",
#  "['Stanford University', 'Bachelor of Arts|BA', 'Bachelor of Laws|LLB']",
#  "['Williams College', 'Bachelor of Arts|BA', 'Yale University']",
#  "['University of Illinois at Chicago', 'University of Chicago', 'Princeton Theological Seminary', 'Master of Divinity|M.Div.']",
#  "['University of Kentucky', 'Bachelor of Arts|BA', 'Harvard University', 'Mid-Career Master of Public Administration|MC/MPA']",
#  "['Barton College|Atlantic Christian College']",
#  "['Howard University', 'Bachelor of Arts|BA', 'Cornell University', 'Master of Arts|MA']",
#  "['Worcester Polytechnic Institute|Worcester Polytechnic Institute (1943)', 'Harvard University|Harvard (1951)']",
#  "['Cecil B. DeMille', 'Fritz Lang', 'Frank Capra', 'Ziegfeld Follies|Ziegfeld', 'Ladies of Leisure']",
#  "['University of Illinois at Urbana–Champaign', 'Bachelor of Arts|BA', 'Juris Doctor|JD', 'Harvard University', 'Master of Laws|LLM']",
#  "['Texarkana College', 'United States Naval Academy', 'Bachelor of Science|BS']",
#  "['United States Naval Academy', 'Bachelor of Science|BS']",
#  "['Accademia di Belle Arti di Firenze|Academy of Fine Arts of Florence']",
#  '[\'Royal Academy of Dramatic Art\', \'Royal Academy of Dramatic Art\', \'The Entertainer (film)|The Entertainer\', \'Tony Richardson\', \'Saturday Night and Sunday Morning (film)|Saturday Night and Sunday Morning\', \'Tom Jones (1963 film)|Tom Jones\', \'Two for the Road (film)|Two for the Road\', \'Scrooge (1970 film)|Scrooge\', \'Annie (1982 film)|Annie\', \'The Dresser (1983 film)|The Dresser\', "Miller\'s Crossing", \'A Man of No Importance (film)|A Man of No Importance\', \'Erin Brockovich (film)|Erin Brockovich\', \'Big Fish\', \'The Bourne Ultimatum (film)|The Bourne Ultimatum\', "Before the Devil Knows You\'re Dead", \'The Bourne Legacy (film)|The Bourne Legacy\', \'Skyfall\', \'British Academy Film Awards|BAFTA\', \'Golden Globe Award|Golden Globe\', \'Emmy Award|Emmy\', \'Screen Actors Guild\', \'Academy Award\', \'Academy Award for Best Actor|Best Actor\', \'Murder on the Orient Express (1974 film)|Murder on the Orient Express\', \'Under the Volcano (film)|Under the Volcano\', \'Academy Award for Best Supporting Actor|Best Supporting Actor\', \'Winston Churchill\', \'BBC\', \'HBO\', \'The Gathering Storm (2002 film)|The Gathering Storm\']',
#  "['University of Nottingham|University College Nottingham']",
#  "['College of Guienne', 'Collège de France|Collège Royal', 'University of Toulouse']",
#  "['University of Missouri|University of Missouri, Columbia', 'Washington University in St. Louis', 'University of Iowa', 'Bachelor of Arts|BA']",
#  "['Clemson University', 'Bachelor of Science|BS']",
#  "['Lincoln High School (Portland, Oregon)|Lincoln High School']",
#  "['Rutgers University–New Brunswick|Rutgers University, New Brunswick', 'Bachelor of Arts|BA']",
#  "['University of Matanzas', 'Cubans|Cuban', 'Child custody|custody', 'Cuban American|Cuban-American']",
#  "['Trinity College (Connecticut)|Trinity College']",
#  "['Amherst College', 'Bachelor of Arts|BA', 'University of Arizona', 'Master of Fine Arts|MFA']",
#  "['University of Michigan|University of Michigan, Ann Arbor', 'Bachelor of Arts|BA', 'Columbia University', 'Juris Doctor|JD']",
#  "['VU University Amsterdam', 'Bachelor of Social Science', 'Master of Social Science', 'University of Groningen']",
#  "['California Institute of Technology', 'Bachelor of Science|BS', 'Stanford University', 'Master of Science|MS', 'Doctor of Philosophy|PhD']",
#  "['Villanova University', 'Bachelor of Arts|BA', 'Salve Regina University', 'Master of Arts|MA', 'Central Michigan University', 'Master of Arts|MA']",
#  "['The Citadel, The Military College of South Carolina|The Citadel', 'Bachelor of Science|BS', 'University of South Carolina, Columbia', 'Bachelor of Laws|LLB']",
#  "['Mines ParisTech|École des Mines de Paris']",
#  "['The Ohio State Buckeyes|Ohio State University', 'East Technical High School']",
#  "['Humboldt University of Berlin|University of Berlin']",
#  "['College of William &amp; Mary|College of William and Mary']",
#  '[\'Bachelor of Arts|B.A.\', \'Master of Arts|M.A.\', \'École Normale Supérieure\', \'Doctoral candidate|Dr. cand.\', \'Fondation Dosne-Thiers|Fondation Thiers\', \'specialist diploma\', "Doctorat d\'État|DrE", \'University of Paris\']',
#  '[\'Government Arts College, Kumbakonam|Government Arts College\', "Pachaiyappa\'s College", \'Trinity College, Cambridge\', \'Bachelor of Science|BSc\']',
#  '[\'Harvard University\', "Bachelor\'s degree|B.A."]',
#  "['Brandeis University', 'Bachelor of Arts|BA', 'University of California, San Diego', 'Master of Arts|MA', 'Humboldt University of Berlin|Humboldt University', 'Doctor of Philosophy|PhD']",
#  "['University of Paris', 'Church of Saint-Sulpice, Paris|Seminary of Saint-Sulpice']",
#  "['École Polytechnique', 'École des Mines', 'University of Paris', 'Doctorat|Dr']",
#  "['University of Colorado Boulder|University of Colorado', 'Bachelor of Arts|BA', 'Hertford College, Oxford', 'Yale University', 'Bachelor of Laws|LLB']",
#  "['Mason Science College|Mason College', 'Trinity College, Cambridge']",
#  "['Somerville College, Oxford|Somerville College', 'University of Oxford|Oxford']",
#  "['Kenyon College', 'Bachelor of Arts|BA', 'Yale University']",
#  "['Washington and Lee University', 'Bachelor of Arts|BA', 'Yale University', 'Juris Doctor|JD', 'New York Theological Seminary', 'Master of Divinity|MDiv']",
#  "['Engineering education|Engineering', 'Riga Polytechnical Institute', 'Bauman Moscow State Technical University|Moscow Highest Technical School']",
#  "['Ruprecht Karl University of Heidelberg|Heidelberg']",
#  "['University of Illinois at Urbana–Champaign|University of Illinois, Urbana-Champaign', 'Bachelor of Arts|BA', 'University of Chicago']",
#  "['University College London', 'University of London', 'University of Greenwich|Woolwich Polytechnic']",
#  "['Page Corps|Corps of Pages', 'Saint Petersburg Imperial University']",
#  "['Presidency College, Kolkata', 'Trinity College, Cambridge', 'B.A.|BA', 'M.A.|MA', 'PhD']",
#  "['University of Athens', 'LL.D.', ':el:Εθνικό Κέντρο Βιβλίου|E.KE.BI / Biblionet', 'University of Paris', 'Doctorat|Dr']",
#  "['Mill Hill School', 'Embassy Theatre (London)|Embassy School of Acting', 'Second Doctor|second incarnation', 'Doctor (Doctor Who)|the Doctor', 'science fiction on television|science-fiction television', 'Doctor Who']",
#  "['Phillips Exeter Academy', 'Dartmouth College', 'Bachelor of Arts|BA']",
#  "['Duke University', 'Bachelor of Arts|BA', 'Master of Business Administration|MBA']",
#  "['Massachusetts Institute of Technology|MIT', 'University of Colorado at Boulder']",
#  "['Academic degree#United Kingdom|Degree in physics', 'Senior School West Buckland School, North Devon', 'Van Mildert College', 'Durham University']",
#  "['Saint Petersburg State University|Saint Petersburg University']",
#  "['Università degli studi di Bari Aldo Moro|University of Bari']",
#  "['Massachusetts Institute of Technology|MIT', 'Swarthmore College|Swarthmore']",
#  "['Jagiellonian University|Kraków Academy']",
#  '[\'Limekilns, New South Wales|Limekilns Public School\', "Patrician Brothers|Patrician Brothers\' School, Bathurst"]',
#  "['Wangaratta High School|Wangaratta State School', 'Dandenong High School|Dandenong State School']",
#  "['Princeton University', 'Bachelor of Arts|BA', 'Northwestern University', 'Juris Doctor|JD']",
#  '[\'Bachelor of Arts|B.A.\', \'Master of Arts|M.A.\', \'Doctoral candidate|Dr. cand.\', \'École Normale Supérieure\', \'Postgraduate studies\', \'Harvard University\', "Doctorat d\'État|DrE", \'University of Paris\']',
#  "['École nationale supérieure des Beaux-Arts|École des Beaux-Arts']",
#  "['Hollywood Professional School', 'Juilliard School', 'Bachelor of Fine Arts|BFA']",
#  "['Modesto Junior College', 'Associate of Arts|AA', 'California State University, Stanislaus', 'Bachelor of Arts|BA', 'Democratic Party (United States)|Democrat', 'California', 'Central Valley (California)|Central Valley', 'United States House of Representatives|House of Representatives', 'Chandra Levy']",
#  "['University of Arkansas', 'Boston Architectural College', 'Harvard University', 'Massachusetts Institute of Technology|MIT']",
#  "['École Polytechnique', 'École nationale des ponts et chaussées|École des Ponts et Chaussées']",
#  "['University of Oslo|University of Christiania']",
#  "['University of California, Berkeley|UC Berkeley']",
#  "['University of Pennsylvania', 'Bachelor of Arts|BA', 'Bachelor of Science|BS', 'Trinity College, Cambridge', 'Master of Arts|MA', 'Yale University', 'Juris Doctor|JD']",
#  "['Yale University', 'Bachelor of Arts|BA', 'Columbia University', 'Doctor of Medicine|MD']",
#  "['Texas State University|Southwest Texas State Teachers College', 'Bachelor of Arts|BA', 'Georgetown University']",
#  "['Brandeis University', 'Bachelor of Arts|B.A.', 'Princeton University', 'Master of Arts|M.A.', 'Ph.D.']",
#  "['Princeton University', 'Columbia University', 'Bachelor of Arts|BA']",
#  "['University of Amsterdam', 'Bachelor of Social Science', 'Master of Social Science']",
#  "['University of Kansas', 'University of Arizona', 'Washburn University', 'Bachelor of Arts|BA', 'Bachelor of Laws|LLB']",
#  "['University College London', 'University of Reading', 'psychology|psychologist', 'computer science|computer scientist']",
#  '[\'Massachusetts Institute of Technology\', \'Bachelor of Science|SB\', "Master\'s degree|SM", \'Harvard University\', \'PhD\']',
#  "['Northwestern University', 'Provo, Utah', 'voice artist', 'actor', 'character actor', 'campy', 'closeted', 'List of Bewitched characters#Uncle Arthur|Uncle Arthur', 'Bewitched', 'Bye Bye Birdie', 'game show', 'Hollywood Squares|The Hollywood Squares', 'Hanna-Barbera']",
#  "['Lincoln University (Pennsylvania)|Lincoln University, Pennsylvania', 'Bachelor of Arts|BA', 'Howard University', 'Bachelor of Laws|LLB', 'Associate Justice of the Supreme Court of the United States|Associate Justice', 'Supreme Court of the United States', 'List of African-American firsts|first African-American', 'Brown v. Board of Education', 'Baltimore', 'Howard University School of Law', 'NAACP Legal Defense and Educational Fund', 'Smith v. Allwright', 'Shelley v. Kraemer', 'Brown v. Board of Education', 'Racial segregation in the United States|racial segregation', 'Equal Protection Clause', 'John F. Kennedy', 'United States Court of Appeals for the Second Circuit|the United States Court of Appeals for the Second Circuit', 'Lyndon B. Johnson', 'United States Solicitor General', 'Tom C. Clark', 'George H. W. Bush', 'Clarence Thomas']",
#  "['Princeton University', 'Bachelor of Arts|BA']",
#  "['University of North Carolina at Chapel Hill', 'Bachelor of Arts|B.A.', 'Columbia University', 'Doctor of Medicine|M.D.']",
#  "['City College of New York', 'Bachelor of Arts|BA']",
#  "['McGill University', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Harvard University', 'Doctor of Philosophy|PhD']",
#  "['Muskingum University', 'Bachelor of Science|BS', 'University of Maryland, College Park']",
#  '[\'Comenius University in Bratislava\', \'Slovaks|Slovak\', \'Prime Minister of Slovakia\', "People\'s Party - Movement for a Democratic Slovakia", \'Czechoslovakia\', \'autocratic\', \'organized crime\']',
#  "['Harvard University', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Stanford University', 'Doctor of Philosophy|PhD']",
#  "['Fort Street High School|Fort Street Model School', 'University of Sydney']",
#  "['Dwight School|Timothy Dwight School', 'Ohio State University']",
#  "['University of Toronto', 'Bachelor of Arts|BA', 'Harvard University', 'Master of Arts|MA']",
#  "['University of Michigan', 'Bachelor of Science|BS', 'Stanford University', 'Master of Science|MS']",
#  "['University of Maryland, College Park|University of Maryland', 'Bachelor of Science|BS', 'Stanford University', 'Master of Science|MS']",
#  "['Old University of Leuven|University of Leuven']",
#  '[\'Paris\', \'France\', \'Paris\', \'France\', \'Neoclassical architecture|Neoclassicalism\', \'Hôtel Alexandre\', "Image:Bibliotheque nationale boul.jpg|thumb|Boullée, \'\'Deuxieme projet pour la&lt;br /&gt; Bibliothèque du Roi\'\' (1785)|alt=", \'France|French\', \'neoclassicism|neoclassical\']',
#  "['College of William &amp; Mary|College of William and Mary']",
#  "['Halki seminary|Patriarchal Theological school (Halki seminary)']",
#  '[\'University of Toronto\', "Queen\'s University at Kingston|Queen\'s University", "Bishop\'s University"]',
# ...
#  "['Syracuse University', 'Bachelor of Science|BS', 'Stanford University', 'Master of Arts|MA']",
#  "['Trinity College, Dublin|Trinity College']",
#  "['Aida Foster stage school|Aida Foster School of Dance']",
#  "['Columbia University', 'Bachelor of Arts|BA']",
#  "['American University of Beirut', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'University of Chicago', 'Doctor of Philosophy|PhD', 'Pashto language|Pashto', 'Dari language|Dari', 'Afghanistan|Afghan', 'United States|American', 'United States Department of State|State Department', 'Center for Strategic and International Studies', 'Washington, D.C.']",
#  "['Whitman College', 'Bachelor of Arts|BA']",
#  '[\'Agnes Scott College\', \'Bachelor of Arts|BA\', \'Harvard University\', \'Master of Public Administration|MPA\', \'Secretary of State of Florida\', \'United States House of Representatives\', \'Republican Party (United States)|Republican\', \'United States House of Representatives elections, 2002|2002 election\', "Florida\'s 13th congressional district", \'United States Senate\', \'2000 United States presidential election|2000 presidential election\', \'Florida election recount\', \'George W. Bush\', \'Al Gore\', \'Key West, Florida\', \'CBS News\', \'Lakeland, Florida\', \'Tampa Tribune\', \'Ben Hill Griffin, Jr.\', \'citrus\', \'Forbes 400\', \'Ben Hill Griffin Stadium\', \'University of Florida\', \'Christian evangelism\', \'Francis Schaeffer\', \'Asheville, North Carolina\', \'Presbyterian Church (U.S.A.)\', \'Presbyterian Church in America\', \'Calvary Chapel\', \'Sarasota, Florida\']',
#  "['University of Puerto Rico, Río Piedras Campus|University of Puerto Rico, Río Piedras', 'Johns Hopkins Bloomberg School of Public Health|Johns Hopkins University']",
#  '["St John\'s College, Cambridge", \'Order of the Garter|KG\', \'Order of the Bath|KB\', \'Privy Council of the United Kingdom|PC\', \'Ben Jonson\', \'Welbeck_Academy|Welbeck Circle\', \'Charles_I_of_England|Charles I\', \'First English Civil War\', \'Cavalier|Royalist\', \'Battle_of_Marston_Moor|Marston Moor\', \'1660 Restoration\', \'Duke of Newcastle\', \'Charles_II_of_England|Charles II\', \'Westminster Abbey\', \'Handsworth, South Yorkshire|Handsworth Manor, Yorkshire\', \'Baron Ogle|Catherine Ogle\', \'Bess of Hardwick\', \'William Cavendish (courtier)|William Cavendish\', \'Charles_Cavendish_(Nottingham_MP)|Charles\']',
#  "['St. Thomas University (New Brunswick)|St. Thomas University']",
#  "['Bachelor of Arts', 'University of Michigan']",
#  "['University of Pennsylvania', 'Bachelor of Arts|BA', 'Villanova University', 'Juris Doctor|JD']",
#  "['Harvard University', 'Bachelor of Arts|BA']",
#  "['University at Albany, SUNY|State University of New York, Albany', 'Bachelor of Arts|BA']",
#  "['Royal College of Veterinary Surgeons|RCVS', 'Glasgow Veterinary College']",
#  "['New Trier High School', 'Illinois State University', 'Bachelor of Arts|BA', 'American Conservatory Theater', 'Master of Fine Arts|MFA']",
#  "['Jurisprudence|Law', 'Humboldt University of Berlin', 'University of Tübingen']",
#  "['Princeton University', 'Bachelor of Arts|BA']",
#  "['Niagara University', 'Columbia University', 'Bachelor of Arts|BA']",
#  "['Boston University', 'University of Costa Rica', 'London School of Economics', 'University of Essex', 'Heredia, Costa Rica|Heredia', 'Costa Rica', 'President of Costa Rica', 'Nobel Peace Prize', 'Central American crisis']",
#  "['Paul M. Hebert Law Center|Louisiana State University, Baton Rouge', 'Bachelor of Laws|LLB']",
#  "['San Jose State University|San Jose State College', 'University of California, Berkeley', 'Bachelor of Science|BS', 'California Institute of Technology', 'Master of Science|MS', 'Doctor of Philosophy|PhD']",
#  "['Bachelor of Arts|BA', 'University of California, Santa Barbara', 'Master of Arts|MA', 'Tufts University']",
#  '[\'Royal Grammar School, High Wycombe\', \'Eton College|Eton\', "King\'s College, Cambridge"]',
#  "['Brooklyn College', 'Bachelor of Arts|BA']",
#  '[\'University of Mumbai\', \'B.A.|BA\', \'Columbia University\', \'M.A.|MA\', \'PhD\', \'London School of Economics\', \'Master of Science|MSc\', \'Doctor of Science|DSc\', "Gray\'s Inn", \'Barrister-at-Law\']',
#  "['Università Cattolica del Sacro Cuore|Università Cattolica of Milan', 'London School of Economics']",
#  "['Queensland Institute of Technology', 'Bachelor of Applied Science|B.AS.', 'University of Queensland']",
#  "['Harvard University', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Doctor of Philosophy|PhD', 'neoconservatism|neoconservative']",
#  "['George Washington University', 'Bachelor of Arts|BA', 'Bachelor of Laws|LLB', 'Federal Bureau of Investigation|FBI', 'Mentorship|protégé', 'J. Edgar Hoover']",
#  "['Doctor of Medicine|M.D.', 'University of Vienna']",
#  "['Reed College', 'Bachelor of Science|BS', 'Rockefeller University', 'Doctorate of Philosophy|PhD']",
#  "['University of Maryland, College Park|University of Maryland', 'University of Michigan', 'Juris Doctor|JD', 'MBA']",
#  "['United States Military Academy', 'Bachelor of Science|BS', 'Harvard University', 'Master of Arts|MA']",
#  "['École normale supérieure (Paris)|Ėcole normale supérieure (Paris)']",
#  "['Church of Saint-Sulpice, Paris|Saint-Sulpice Seminary']",
#  "['University of Tokyo|Tokyo Imperial University']",
#  "['University of Göttingen', 'Germany|German', 'Philodorian', 'Sparta', 'Greek mythology']",
#  "['French nobility|nobleman', 'linguist', 'oriental studies|orientalist', 'Ustazade Silvestre de Sacy', 'Civil law notary|notary', 'Jansenist', 'Louis-Isaac Lemaistre de Sacy']",
#  '[\'Southern Nazarene University\', \'Bachelor of Arts|BA\', \'Yale University\', \'Bachelor of Divinity|BDiv\', \'Bachelor of Laws|LLB\', "St Antony\'s College, Oxford", \'Doctor of Philosophy|DPhil\']',
#  "['Music conservatories of Naples|Conservatory of San Pietro a&lt;br&gt;Majella', 'Milan Conservatory']",
#  "['Stanford University', 'Bachelor of Arts|BA', 'University College, Oxford', 'Master of Philosophy|MPhil', 'Doctor of Philosophy|DPhil', 'Columbia University', 'Master of Public Health|MPH', 'New York University']",
#  "['University of Western Australia|UWA', 'Columbia Law School|Columbia']",
#  "['Stanford University', 'Bachelor of Arts|BA', 'University of Wisconsin–Madison|University of Wisconsin, Madison', 'Master of Arts|MA', 'University of California, Santa Cruz', 'Doctor of Philosophy|PhD']",
#  "['Stony Brook University', 'Queens College, City University of New York|Queens College']",
#  "['Butler University|Butler College', 'Radcliffe College', 'Yale Drama School']",
#  "['Tufts University', 'Bachelor of Science|BS', 'Bachelor of Arts|BA', 'Master of Arts|MA', 'Doctor of Philosophy|PhD', 'London School of Economics']",
#  '["St Benedict\'s School, Ealing|St Benedict\'s School", \'Balliol College, Oxford\']',
#  "['Dwight School|Timothy Dwight School', 'Harvard University', 'Bachelor of Arts|AB']",
#  "['University College London|University of London', 'University of Munich']",
#  "['Imperial Moscow University|Imperial Moscow University (1897)', 'Russian language|Russian', 'Expressionism', 'Silver Age', 'Literary realism|realist', 'Naturalism (literature)|naturalist', 'Russian symbolism|symbolist', 'Oryol', 'Moscow', 'Saint Petersburg', 'Poles|Polish', 'Ukrainians|Ukrainian', 'Finns|Finnish', 'Maxim Gorky', 'Sreda (literary group)|Sreda', 'Znanie (publishing company)|Znanie', '1905 Russian Revolution|first Russian revolution', 'The Seven Who Were Hanged', 'The Life of Man', 'Tsar Hunger', 'Konstantin Stanislavsky', 'Moscow Art Theatre', 'Vsevolod Meyerhold', 'Russian futurism|Futurists', 'Finland', 'Bolshevik', 'United States', 'The Rape of the Sabine Women (play)|The Rape of the Sabine Women', 'He Who Gets Slapped', 'MGM', 'Thomas Seltzer (translator)|Thomas Seltzer', 'Poor Murderer', 'Pavel Kohout', 'Image:Bulla Andreyev.jpg|thumb|right|Leonid Andreyev and his second wife, Anna', 'Taras Shevchenko', 'Daniil Andreyev', 'Roza Mira', 'H. P. Lovecraft', 'S.T. Joshi', 'Robert E. Howard']",
#  "['Hertford College, Oxford', 'Charles_I_of_England|Charles I', 'First English Civil War', 'Lord Chancellor', 'Long Parliament', 'Cavalier|Royalists', 'constitutional monarchy', 'Parliament_of_England|Parliament', 'Episcopal polity|Episcopalian', 'Church of England', 'Puritan', 'York', 'Ralph_Hopton,_1st_Baron_Hopton|Sir Ralph Hopton', 'Covenanters', 'Charles_II_of_England|Prince of Wales', 'West Country', 'Second English Civil War', 'Charles_II_of_England|Charles II', 'Paris', 'Madrid', 'Third English Civil War', 'Restoration (1660)|restored to the throne in 1660', 'Anne Hyde|Anne', 'James_II_of_England|James II', 'Mary_II_of_England|Mary', 'Anne,_Queen_of_Great_Britain|Anne', 'Second Anglo-Dutch War', 'The History of the Rebellion', 'Cornelis Janssens van Ceulen]]', 'Dinton, Wiltshire', 'Henry Hyde (died 1634)|Henry Hyde', 'Nicholas Hyde', 'Lord Chief Justice', 'Lawrence Hyde (attorney-general)|Lawrence', 'Attorney_general|legal advisor', 'Anne of Denmark', 'James_VI_and_I|James I']",
#  "['Leyton', 'Wanstead', 'Essex', 'diplomat', 'Elizabethan era|Elizabethan', 'James I of England|Jacobean', 'Mughal Empire', 'Ottoman Empire', 'Holy Roman Empire', 'House of Commons of England|House of Commons', 'File:SIR THOMAS STOOD BEFORE THE MOGUL.gif|thumb|left|Sir Thomas standing before the Great Moghul', 'Leyton', 'Wanstead', 'Essex', 'Norfolk', 'Magdalen College, Oxford', 'Middle Temple', 'esquire', 'Elizabeth I of England', 'knight', 'James I of England|James I', 'Henry Frederick Stuart|Henry, Prince of Wales', 'Elizabeth of Bohemia|Elizabeth', 'West Indies', 'The Guianas|Guiana', 'Amazon River', 'Lake Parime', 'El Dorado', 'Thomas Harriot', 'File:Jahangir investing a courtier with a robe of honour watched by Sir Thomas Roe, English ambassador to the court of Jahangir at Agra from 1615-18, and others.jpg|thumb|Jahangir investing a courtier with a robe of honour watched by Sir Thomas Roe, English ambassador to the court of Jahangir at Agra from 1615–18, and others']",
#  "['Northern Secondary School (Toronto)|Northern Secondary School', 'Ontario College of Art', 'Royal College of Art']",
#  '["St. Paul\'s School (New Hampshire)|St. Paul\'s School", \'Yale College\', \'Columbia Law School\']',
#  "['University of Vienna', 'Triple Goddess (Neopaganism)|Goddess', 'Pentagram]].']",
#  "['Ravenshaw Collegiate School', 'Presidency College, Kolkata|Presidency College, Calcutta', 'Scottish Church College', 'Fitzwilliam_College,_Cambridge#History|Fitzwilliam Hall', 'University of Calcutta', 'B.A.', 'University of Cambridge']",
#  "['Yale University', 'Bachelor of Arts|BA', 'Columbia University', 'Juris Doctor|JD']",
#  "['University of Halle-Wittenberg|University of Halle']",
#  '[\'Stellenbosch University|Victoria College, Stellenbosch\', "Christ\'s College, Cambridge", \'Inns of Court\']',
#  "['Stonehill College', 'Bachelor of Arts|BA', 'Pontifical Gregorian University', 'Bachelor of Sacred Theology|STB', 'Harvard University', 'Master of Arts|MA']",
#  '[\'Finance University under the Government of the Russian Federation|Moscow Finance Institute\', \'Soviet people|Soviet\', \'Russia\', \'dissolution of the Soviet Union\', \'Moscow\', \'Russian Soviet Federative Socialist Republic\', \'Ministry of Finance (Soviet Union)|Ministry of Finance\', \'History of the Soviet Union (1964–1982)|Brezhnev Era\', \'Gosplan|State Planning Committee\', \'State Committee on Prices\', \'History of the Soviet Union (1982–1991)|Gorbachev Era\', \'Nikolai Ryzhkov\', \'Premier of the Soviet Union|Prime Minister of the Soviet Union\', \'Valentin Pavlov#Pavlov monetary reform|initiated the 1991 Soviet monetary reform\', \'Soviet rouble\', \'Soviet Union\', "1991 Soviet coup d\'état attempt", \'Ivan Silayev\', \'Russian Soviet Federative Socialist Republic\']',
#  "['École nationale des beaux-arts|École Nationale des Beaux-Arts']",
#  "['Bachelor of Arts|B.A.', 'History', 'University of Dallas']",
#  "['Phillips Exeter Academy', 'Stevens Institute of Technology', 'Bachelor of Science|BS']",
#  '[\'Fordham University\', \'Bachelor of Science|BS\', "St. John\'s University (New York City)|St. John\'s University, New York", \'Bachelor of Laws|LLB\']',
#  "['Cornell University', 'Bachelor of Arts|BA', 'University of Michigan', 'Juris Doctor|JD']",
#  "['Stanford University', 'Bachelor of Arts|B.A.', 'New York University School of Medicine|New York University Medical School', 'Doctor of Medicine|M.D.', 'William Alanson White Institute|William Alanson White Institute of Psychoanalysis']",
#  "['Royal College of Art|National Art Training School']",
#  "['University of Delhi', 'B.A.|BA', 'Syracuse University', 'PhD']",
#  "['Massachusetts Institute of Technology', 'Bachelor of Science|SB', 'Harvard University', 'Master of Arts|AM', 'Doctor of Philosophy|PhD']",
#  "['Carnegie Mellon University|Carnegie Mellon', 'Doctor of Philosophy|Ph.D.', 'Stanford University|Stanford', 'Master of Business Administration|MBA', 'Massachusetts Institute of Technology|MIT', 'Bachelor of Sciences|B.Sc']",
#  "['Erasmus University', 'Doctor of Philosophy|PhD']",
#  "['Humboldt University of Berlin|University of Berlin']",
#  "['Art Institute of Chicago', 'Bachelor of Fine Arts|BFA']",
#  "['Unitarian College, Manchester|Manchester College, York']",
#  "['Brigham Young University', 'Bachelor of Music|B.M.']",
#  "['University of Illinois at Urbana–Champaign|University of Illinois']",
#  "['University of Heidelberg', 'University of Lausanne', 'Humboldt University of Berlin|University of Berlin', 'University of Rostock', 'Dr. phil. hab.']",
#  '[\'Dartington Hall|Dartington Hall School\', \'Bryanston School\', \'Central School of Art\', \'East Anglian School of Painting and Drawing\', "Goldsmiths\' College"]',
#  "['Middlebury College', 'Bachelor of Arts|BA']",
#  "['Bachelor of Arts|A.B.', 'Harvard College']",
#  "['Alliant International University|Alliant International University, San Diego', 'Bachelor of Arts|BA', 'New York University', 'Master of Fine Arts|MFA']",
#  "['Straight University', 'Bachelor of Laws|LLB']",
#  "['Lawrenceville School', 'Harvard University', 'United States Military Academy|West Point']",
#  "['San Jose State University', 'Bachelor of Arts|BA', 'University of Wisconsin–Madison', 'Bachelor of Laws|LLB']",
#  "['University of Michigan|University of Michigan, Ann Arbor', 'Weill Cornell Medical College|Cornell University']",
#  ...]

# %% [markdown]
# So... we've got some wierd stuff in there. We're going to keep that in mind for later. It looks like Bachelor of Arts is going to be harder to eliminate than I thought, so we will leave it in for now. In the end, this will likely be fine as I plan on doing a value count of the top schools. If *Bachelor of Arts* shows up as a top school, we can just filter it out. Don't worry, I won't be fooled into thinking *Bachelor of Arts* is an institution.

# %% [markdown]
# #### Wrangling with `occupation`

# %%
wikipeople_employed = wikipeople[pandas.notnull(wikipeople['occupation'])]
wikipeople_employed.head()
# Out:
#                      name  birth_date  \
# 1           Aldous Huxley        1894
# 5        Alfred Hitchcock        1899
# 6            Alfred Nobel        1833
# 7   Alexander Graham Bell        1847
# 10            A. A. Milne        1882
#
#                                            occupation  \
# 1         | occupation = {{hlist|Writer|philosopher}}
# 5   | occupation = {{hlist|Film director|film prod...
# 6   | occupation         = Chemist, engineer, inve...
# 7   | occupation = {{hlist |Inventor |Scientist}} ...
# 10          | occupation = Novelist, playwright, poet
#
#                                             education
# 1         ['Eton College', 'Balliol College, Oxford']
# 5   ['Salesian College, Battersea', "St Ignatius' ...
# 6                                                  []
# 7   ['University of Edinburgh', 'University Colleg...
# 10                     ['Trinity College, Cambridge']

# %% [markdown]
# Let's get rid of some of this extra text. We are making sure to do this in the `wikipeople` dataframe, and then we will recreate the `wikipeople_occupied` dataframe again later to take a look.

# %%
def erase1(thing):
    if 'occupation' in thing:
        if pandas.isnull(re.search('.*=(.*)',thing)):
            return ''
        return re.search('.*=(.*)',thing).group(1)
    else:
        return thing

# %%
wikipeople_employed.dtypes
# Out:
# name          object
# birth_date     int64
# occupation    object
# education     object
# dtype: object

# %% [markdown]
# first we have to convert the column to type `str`

# %%
wikipeople['occupation'] = wikipeople['occupation'].astype('str')

# %%
wikipeople['occupation'] = [ erase1(job) for job in wikipeople['occupation'] ]
wikipeople.head()
# Out:
#                   name  birth_date                     occupation  \
# 0         Alain Connes        1947                            nan
# 1        Aldous Huxley        1894   {{hlist|Writer|philosopher}}
# 2  Arthur Schopenhauer        1788                            nan
# 3      Albert Einstein        1879                            nan
# 4     Alfred Korzybski        1879                            nan
#
#                                            education
# 0  ['École Normale Supérieure', 'Pierre and Marie...
# 1        ['Eton College', 'Balliol College, Oxford']
# 2                                                 []
# 3  ['ETH Zurich|Federal Polytechnic School', 'Zur...
# 4                ['Warsaw University of Technology']

# %% [markdown]
# And then let's make everything lowercase.

# %%
wikipeople['occupation'] = [job.lower() for job in wikipeople['occupation']]
wikipeople.head()
# Out:
#                   name  birth_date                     occupation  \
# 0         Alain Connes        1947                            nan
# 1        Aldous Huxley        1894   {{hlist|writer|philosopher}}
# 2  Arthur Schopenhauer        1788                            nan
# 3      Albert Einstein        1879                            nan
# 4     Alfred Korzybski        1879                            nan
#
#                                            education
# 0  ['École Normale Supérieure', 'Pierre and Marie...
# 1        ['Eton College', 'Balliol College, Oxford']
# 2                                                 []
# 3  ['ETH Zurich|Federal Polytechnic School', 'Zur...
# 4                ['Warsaw University of Technology']

# %% [markdown]
# Notice how *'Writer'* is now *'writer'*? <br>
# Let's look at the rows that have occupations.

# %%
wikipeople_employed_temp = wikipeople[wikipeople['occupation'] != 'nan']
wikipeople_employed = wikipeople_employed_temp[wikipeople_employed_temp['occupation'] != '']
wikipeople_employed.head()
# Out:
#                      name  birth_date  \
# 1           Aldous Huxley        1894
# 5        Alfred Hitchcock        1899
# 6            Alfred Nobel        1833
# 7   Alexander Graham Bell        1847
# 10            A. A. Milne        1882
#
#                                            occupation  \
# 1                        {{hlist|writer|philosopher}}
# 5    {{hlist|film director|film producer|actor|scr...
# 6    chemist, engineer, inventor, businessman,  ph...
# 7                                   &quot;n&quot;}}}}
# 10                         novelist, playwright, poet
#
#                                             education
# 1         ['Eton College', 'Balliol College, Oxford']
# 5   ['Salesian College, Battersea', "St Ignatius' ...
# 6                                                  []
# 7   ['University of Edinburgh', 'University Colleg...
# 10                     ['Trinity College, Cambridge']

# %% [markdown]
# Looking much better. The `occupation` column is still ugly, but now we can pick our top occupations and search the `occupation` strings for those occupations to make dummy variables later on.

# %% [markdown]
# #### Setting `name` field as index

# %%
wikipeople = wikipeople.set_index('name')

# %%
wikipeople.head()
# Out:
#                      birth_date                     occupation  \
# name
# Alain Connes               1947                            nan
# Aldous Huxley              1894   {{hlist|writer|philosopher}}
# Arthur Schopenhauer        1788                            nan
# Albert Einstein            1879                            nan
# Alfred Korzybski           1879                            nan
#
#                                                              education
# name
# Alain Connes         ['École Normale Supérieure', 'Pierre and Marie...
# Aldous Huxley              ['Eton College', 'Balliol College, Oxford']
# Arthur Schopenhauer                                                 []
# Albert Einstein      ['ETH Zurich|Federal Polytechnic School', 'Zur...
# Alfred Korzybski                   ['Warsaw University of Technology']

# %% [markdown]
# Huh. I was scared of duplicate names, but it seems wikipedia has already banned pages with the same title. This makes sense for the site, and sure is nice for my dataset.

# %% [markdown]
# ## College Count Dataframe
#     Now, we will construct another dataframe representing each college and their count.

# %% [markdown]
# #### Arrays to pass into the Dataframe

# %%
wikipeople.dtypes
# Out:
# birth_date     int64
# occupation    object
# education     object
# dtype: object

# %%
wikipeople['education'][0]
# Out:
# "['École Normale Supérieure', 'Pierre and Marie Curie University']"

# %% [markdown]
# Ruh roh. I thought I had made the education field all arrays, but it looks like they are strings... this is bad.

# %%
def string_to_array(thing):
    # if it is already an array, return
    if isinstance(thing, list):
        return thing
    # else turn it into an array
    array = []
    while len(thing) > 2:
        temp = ' '
        r = re.search('\'([^,]*)\'', thing)
        if r:
            temp = r.group(1)
            array.append(temp)
        else:
            return array
        thing = thing[len(temp)+4:]
    return array

# %%
string_to_array( wikipeople['education'][0] )
# Out:
# ['École Normale Supérieure', 'Pierre and Marie Curie University']

# %%
wikipeople_temp = wikipeople

# %%
wikipeople_temp['education'] = [ string_to_array(schools) for schools in wikipeople['education'] ]
wikipeople_temp
# Out:
#                      birth_date                     occupation  \
# name
# Alain Connes               1947                            nan
# Aldous Huxley              1894   {{hlist|writer|philosopher}}
# Arthur Schopenhauer        1788                            nan
# Albert Einstein            1879                            nan
# Alfred Korzybski           1879                            nan
# ...                         ...                            ...
# Liezl van der Merwe        1980           member of parliament
# Andrea Romero                 0                            nan
# Joy Garratt                1952                            nan
# Crystal Watson             1983                            nan
# Uri Mayerfeld                 0               [[rosh yeshiva]]
#
#                                                              education
# name
# Alain Connes         [École Normale Supérieure, Pierre and Marie Cu...
# Aldous Huxley                                           [Eton College]
# Arthur Schopenhauer                                                 []
# Albert Einstein      [ETH Zurich|Federal Polytechnic School, Zurich...
# Alfred Korzybski                     [Warsaw University of Technology]
# ...                                                                ...
# Liezl van der Merwe                                                 []
# Andrea Romero               [Stanford University, Bachelor of Arts|BA]
# Joy Garratt          [Excelsior College, Bachelor of Arts|BA, Unive...
# Crystal Watson       [University of Colorado Boulder, Johns Hopkins...
# Uri Mayerfeld                                                       []
#
# [284578 rows x 3 columns]

# %%
# the list of colleges attended by some famous person
colleges = []
for schools in wikipeople['education']:
    for school in schools:
        if school not in colleges:
            colleges.append(school)
colleges
# Out:
# ['École Normale Supérieure',
#  'Pierre and Marie Curie University',
#  'Eton College',
#  'ETH Zurich|Federal Polytechnic School',
#  'Zurich',
#  'University of Zurich',
#  'Warsaw University of Technology',
#  'University of Edinburgh',
#  'University College London',
#  'St. Petersburg University',
#  'New York University',
#  'Technical University of Berlin',
#  'Technical University of Munich',
#  'Karlsruhe Institute of Technology',
#  'University of Algiers',
#  'Columbia University',
#  'University of Strasbourg',
#  'University of Lyon',
#  'Lycée Henri-IV',
#  'École Polytechnique|École Polytech',
#  'École des ponts ParisTech|École des Ponts',
#  'Malvern College',
#  'Tonbridge School',
#  'Eastbourne College',
#  'occultist',
#  'ceremonial magic',
#  'Thelema',
#  'Æon of Horus',
#  'Royal Leamington Spa',
#  'Warwickshire',
#  'Christian fundamentalism|fundamentalist Christian',
#  'Plymouth Brethren',
#  'Western esotericism',
#  'University of Cambridge',
#  'British intelligence agency',
#  'Hermetic Order of the Golden Dawn',
#  'Samuel Liddell MacGregor Mathers',
#  'Charles Henry Allan Bennett|Allan Bennett',
#  'Boleskine House',
#  'Loch Ness',
#  'Oscar Eckenstein',
#  'Hindu',
#  'Buddhist',
#  'Rose Edith Kelly',
#  'Cairo',
#  'Aiwass',
#  'The Book of the Law',
#  'True Will',
#  'Magick (Thelema)|magick',
#  '1905 Kanchenjunga expedition|an unsuccessful attempt to climb Kanchenjunga',
#  'George Cecil Jones',
#  'A∴A∴',
#  'Ordo Templi Orientis',
#  'First World War',
#  'Abbey of Thelema',
#  'Cefalù',
#  'libertine',
#  'recreational drug',
#  'bisexual',
#  'individualist',
#  'social critic',
#  'Satanist',
#  'counterculture',
#  'Sherborne School',
#  'Bachelor of Arts|BA',
#  'Master of Arts|MA',
#  'Princeton University',
#  'National Autonomous University of Mexico',
#  'University of Colorado at Boulder',
#  'University of Utah',
#  'University of Paris',
#  'Harvard University',
#  'Roman Seminary',
#  'Pontifical Roman Athenaeum Saint Apollinare',
#  'University of Padua',
#  'Rostov State University',
#  'Santa Monica College',
#  'University of Wisconsin–Superior',
#  'University of Glasgow',
#  'University of Oxford|Oxford',
#  'Collège des Quatre-Nations',
#  'University of Marburg',
#  'Sherwood College',
#  'Nainital',
#  'Kirori Mal College',
#  'Delhi University',
#  'The Times of India',
#  'École Nationale des Ponts et Chaussées',
#  'University of Westminster|Royal Polytechnic Institution',
#  'Imperial College London',
#  'Aligarh Muslim University',
#  'University of Oslo',
#  'The Leys School',
#  'University of Oxford',
#  'University of Montpellier',
#  'University of Nancy',
#  'La Martiniere Lyon',
#  'University of Copenhagen',
#  'Victoria University of Manchester|University of Manchester',
#  'University of Michigan',
#  'Oklahoma State University',
#  'Yale Law School',
#  'Jazz Age',
#  'Broadway theatre|Broadway',
#  'University of Tübingen|Eberhard Karl University of Tübingen',
#  'Julius Maximilian University of Würzburg',
#  'Humboldt University of Berlin|Friedrich Wilhelm University',
#  'Osaka University',
#  'Cowbridge Grammar School',
#  'Royal Academy of Dramatic Art',
#  'University of Birmingham',
#  'Edwina Currie',
#  'I.M. Sechenov First Moscow State Medical University|First Moscow State Medical University',
#  'Saint Petersburg State University',
#  'Uppsala University',
#  'Moscow State University',
#  'Lebedev Physical Institute|FIAN',
#  'University of Delhi',
#  'B.A.|BA',
#  'M.A.|MA',
#  'SOAS University of London',
#  'Master of Philosophy|MPhil',
#  'Humboldt University of Berlin|University of Berlin',
#  'Hochschule für die Wissenschaft des Judentums|Higher Institute for Jewish Studies',
#  'rabbi',
#  'Judaism|Jewish',
#  'Jewish mysticism',
#  'Jewish Theological Seminary of America',
#  'Jewish philosophy',
#  'civil rights movement',
#  'University of Łódź',
#  'Hebrew University of Jerusalem',
#  'Tel Aviv University',
#  'Cornell University',
#  'San Diego State University',
#  'Carnegie Mellon University',
#  'University of London',
#  'Massachusetts Institute of Technology',
#  'Georgetown University',
#  'Bachelor of Science|BS',
#  'Yale University',
#  'Juris Doctor|JD',
#  'Talmud Torah',
#  'University of Leiden',
#  'Aarhus University',
#  'Lund University',
#  'University of Texas at Austin',
#  'Trinity College Dublin',
#  'École Polytechnique',
#  'California Institute of Technology',
#  'Gonzaga University',
#  'Kenyon College',
#  'University of Toronto',
#  'University of Western Australia',
#  'Bachelor of Laws|LLB',
#  'Australian National University',
#  'Bard College',
#  'University of Washington',
#  'McGill University',
#  'Mathematics',
#  'Doctor of Philosophy|Ph.D.',
#  'University of Paris|Sorbonne',
#  'Downside School',
#  'Waltrip High School',
#  'University of St. Thomas (Houston)|University of Saint Thomas',
#  'Yeshiva University',
#  'Sarah Lawrence College',
#  'University of Wisconsin–Madison',
#  'Bachelor of Arts|B.A.',
#  'Gamaliel',
#  'Kabul University',
#  'Al-Azhar University',
#  'Bachelor of Fine Arts|BFA',
#  'Western Michigan University',
#  'University of Arizona',
#  'Hamilton College (New York)|Hamilton College',
#  'Syracuse University',
#  'Richmond upon Thames College|Twickenham College of Technology',
#  'University of East Anglia',
#  'Climatic Research Unit',
#  'Drake University',
#  'University of Harderwijk',
#  'Massachusetts Institute of Technology|MIT',
#  'University of Massachusetts Amherst',
#  'London School of Economics',
#  'Lycée Louis-le-Grand',
#  'University of Edinburgh Medical School',
#  'Braunschweig University of Technology|Collegium Carolinum',
#  'University of Göttingen',
#  'University of Helmstedt',
#  'Widener University|Pennsylvania Military College',
#  'American Academy of Dramatic Arts',
#  'Amherst College',
#  'Charles University in Prague|University of Prague',
#  'University of Vienna',
#  'Jagiellonian University',
#  'United States Air Force Academy',
#  'University of Kansas',
#  'University of Chicago',
#  'Baoding Military Academy',
#  'Imperial Japanese Army Academy',
#  'George Washington University',
#  'Master of Business Administration|MBA',
#  'University of Cape Town',
#  'University of Minnesota Medical Center|University of Minnesota',
#  'Mount Holyoke College',
#  'Master of Fine Arts|MFA',
#  'Dragonslayer (1981 film)|Dragonslayer',
#  'Broadway theater|Broadway',
#  'musical theater|musical',
#  'Titanic (musical)|Titanic',
#  'Pittsburgh',
#  'Victoria Clarke',
#  'Yale School of Drama',
#  'Yale Repertory Theater',
#  'Tales from the Vienna Woods',
#  'Crocodile Dundee',
#  'ovarian cancer',
#  'University of Pittsburgh',
#  'Pittsburgh Musical Theater',
#  'Theatre in Pittsburgh|Pittsburgh theatre',
#  'Trafford Tanzi|Teaneck Tanzi: The Venus Flytrap',
#  'The Marriage of Figaro (play)|The Marriage of Figaro',
#  'Arms and the Man',
#  'Strange Interlude',
#  'Titanic (musical)|Titanic: A New Musical',
#  'Kenny (1988 film)|Kenny',
#  'The Big Picture (1989 film)|The Big Picture',
#  'Penn &amp; Teller Get Killed',
#  'Blown Away (1994 film)|Blown Away',
#  'Joe the King',
#  'Never Again (2001 film)|Never Again',
#  'Northern Exposure',
#  'The Equalizer',
#  'Once a Hero',
#  'Moonlighting (TV series)|Moonlighting',
#  'Sex And The City',
#  'Law &amp; Order',
#  'Matlock (TV series)|Matlock',
#  'Mayflower Madam',
#  'The Stepford Husbands',
#  'Imperial–Royal Polytechnic Institute',
#  'Prague Polytechnic',
#  'Harvard College',
#  'political science',
#  'Johns Hopkins University',
#  'Alcorn State University',
#  'West Virginia University',
#  'The Catholic University of America',
#  'Harrow High School|Harrow County School for Boys',
#  'Rutgers University',
#  'Colgate University',
#  'Brown University',
#  'Bachelor of Arts|AB',
#  'Ohio State University',
#  'Chouinard Art Institute',
#  'Gustavus Adolphus College',
#  'University of Minnesota',
#  'Symbionese Liberation Army',
#  'Patty Hearst',
#  'File:Camilla Hall as a child.jpg|thumb|left|border|Camilla Hall as a child',
#  'PhD',
#  'Oregon State University',
#  'Case Western Reserve University|Case Institute of Technology',
#  'United States Military Academy',
#  'University of Königsberg',
#  'Ball State University',
#  'American Conservatory Theater',
#  'Goddard College',
#  'Calvert Hall College High School',
#  'Towson University',
#  'Providence College',
#  'Bronx High School of Science',
#  'Transylvania University',
#  'William Ellis School',
#  'Phillips Exeter Academy',
#  'Stanford University',
#  'University of Oregon',
#  'Helix High School',
#  'Actors Studio',
#  'Dartmouth College',
#  'Emerson College',
#  'Rescue Me (U.S. TV series)|Rescue Me',
#  'George Stacy',
#  'Marc Webb',
#  'The Amazing Spider-Man (2012 film)|The Amazing Spider-Man',
#  'Ivan Reitman',
#  'Draft Day',
#  'List of Ice Age characters#Diego|Diego',
#  "'Ice Age'",
#  "Ice Age'",
#  'Sex &amp; Drugs &amp; Rock &amp; Roll (TV series)|Sex &amp; Drugs &amp; Rock &amp; Roll',
#  'FX (TV channel)|FX',
#  'Shippensburg University of Pennsylvania|Shippensburg State College',
#  'Los Angeles Harbor College',
#  'University of Southern California',
#  'Rhode Island School of Design',
#  'University of Greifswald',
#  'Humboldt University of Berlin',
#  'University of Pennsylvania',
#  'German-language',
#  'University of St Andrews',
#  'Leipzig University',
#  'Martin Luther University of Halle-Wittenberg|University of Halle',
#  'Dr. phil. hab.',
#  'University of Virginia',
#  'University of Canterbury#History|Canterbury College',
#  'University of New Zealand',
#  'University of Berlin',
#  'University of Würzburg',
#  'University of Jena',
#  'Society of Apothecaries',
#  'Yale College',
#  'Cowan Bridge School',
#  'Lancashire',
#  'University of Idaho',
#  'chemical engineering',
#  'Food engineering|food engineer',
#  'doughnut',
#  'science fiction author|science-fiction author',
#  'Lensman',
#  'Skylark (series)|Skylark',
#  'space opera',
#  'École Normale Supérieure|École préparatoire',
#  'Vassar College',
#  'Ludwig Maximilian University of Munich',
#  'Leiden University',
#  'University of Amsterdam',
#  'University of Wittenberg',
#  'City of London School',
#  'University of Graz',
#  'Collège de Montaigu',
#  'University of Paris|Paris',
#  'University of Turin',
#  'Scuola Normale Superiore di Pisa|Scuola Normale Superiore',
#  'Free University of Brussels (1834–1969)|Free University of Brussels',
#  'Master of Arts|AM',
#  'University of Alabama',
#  'Sydney Boys High School',
#  'University of Sydney',
#  'University of Milan',
#  'University of Texas at Austin|University of Texas',
#  'City College of New York',
#  'Neighborhood Playhouse School of the Theatre',
#  'Hofstra University',
#  'University of Bonn',
#  'German Charles-Ferdinand University',
#  'ETH Zürich',
#  'University of Leipzig',
#  'Bachelor of Arts|A.B.',
#  'Master of Arts|A.M.',
#  'University of Geneva',
#  'HEC Paris',
#  'University of Poitiers',
#  'Dwight School|Timothy Dwight School',
#  'New York University School of Law',
#  'University of Lisbon',
#  'Northampton Grammar School',
#  'Mill Hill School',
#  'Toledo Infantry Academy|Infantry Academy of Toledo',
#  'University of Giessen',
#  'Potchefstroom University for Christian Higher Education|Potchefstroom University',
#  'Royal College of Chemistry',
#  'Military Engineering-Technical University',
#  'Dr. jur.',
#  'Dr. rer. pol',
#  'Duke University',
#  'University of Heidelberg',
#  'University of Kiel',
#  'University of Wales',
#  'University of Sassari',
#  'University of Oslo|Royal Frederick University',
#  'Schulpforta',
#  'University of Bologna',
#  'Peabody High School (Pennsylvania)|Peabody High School',
#  'ETH Zurich|Swiss Federal Polytechnic',
#  'École Centrale Paris',
#  'Johns Hopkins School of Medicine',
#  'University of Helsinki',
#  'B.A.',
#  'M.A.',
#  'LL.B.',
#  'University of Altdorf',
#  'Northwestern University',
#  'Master of Science|MS',
#  'Martin Luther University of Halle-Wittenberg|University of Wittenberg',
#  's School (London)|St Paul',
#  'Slade School of Art',
#  'Mowbray House School',
#  'Knox Grammar School',
#  'Telopea Park School',
#  'Canberra Grammar School',
#  'Highgate School',
#  'Pittsburgh Playhouse',
#  'Purdue University',
#  'Master of Arts|M.A.',
#  'Pasadena Playhouse',
#  'Gymnasium illustre zu Stuttgart',
#  'Reed College',
#  'Ithaca College',
#  'University of Aberdeen',
#  'Eötvös Loránd University',
#  'Doctor of Philosophy|PhD',
#  'University of Pavia',
#  'Los Angeles City College',
#  'Technische Universität München',
#  'University of Munich',
#  'Royal College of Science',
#  'University of Basel',
#  'Martin Luther University of Halle-Wittenberg',
#  'Staatsexamen',
#  'George Fox University',
#  'Cuyahoga Community College',
#  'California Institute of Technology|Caltech',
#  'Bachelor of Science|B.S.',
#  'Harvard University|Harvard',
#  'Doctorate|Ph.D.',
#  'Kyoto University',
#  'Randwick Public School',
#  'Abbotsholme College',
#  'University of Melbourne',
#  'Columbia University School of Mines',
#  'University of Breslau',
#  'Trinity School (New York City)|Trinity School',
#  'Phillips Academy',
#  'Thacher School',
#  'Fessenden School',
#  'Rice University',
#  'Swansea Grammar School',
#  'University of Illinois at Urbana Champaign',
#  'Harrow School',
#  'University of Nebraska-Lincoln',
#  'Bolton School',
#  'University of Sheffield',
#  'Bachelor of Science',
#  'Master of Arts',
#  'Doctor of Philosophy',
#  'Collegium Fridericianum',
#  'University of Stirling',
#  'Bachelor of Architecture|BArch',
#  'Master of Architecture|MArch',
#  'Visva-Bharati University',
#  'University College Dublin',
#  'Great Ayton',
#  'Tübinger Stift',
#  'University of Tübingen',
#  'University of Wisconsin–Madison|University of Wisconsin',
#  'UCLA',
#  'University of Freiburg',
#  'Phillips Academy|Phillips Academy Andover',
#  'Plympton Grammar School|Plympton Free Grammar School',
#  'University of New Hampshire',
#  'The College of William &amp; Mary|College of William and Mary',
#  'Rutlish School',
#  'Apprenticeship',
#  'University of Saskatchewan',
#  'DePauw University',
#  'Queen Mary University of London',
#  'Eötvös Loránd University|Pázmány Péter University',
#  'ETH Zurich|ETH Zürich',
#  'College of William and Mary',
#  'Georgia Southwestern State University|Georgia Southwestern College',
#  'Georgia Institute of Technology',
#  'United States Naval Academy',
#  'Union College',
#  'Wayne State University',
#  'Catechetical School of Alexandria',
#  'University of Iowa',
#  'University of Erlangen',
#  'University of Exeter',
#  'Master of Laws|LLM',
#  'University of Ingolstadt',
#  'University of Florida',
#  'United States Military Academy|U.S. Military Academy',
#  'Salisbury Cathedral School',
#  'University of Bordeaux',
#  'Michigan State University',
#  'Western Michigan University Cooley Law School|Thomas M. Cooley Law School',
#  'Collège Stanislas de Paris|Collège Stanislas',
#  'Specialist diploma|certificate of specialist',
#  'legal medicine',
#  'M.D.',
#  'University of Vermont',
#  'Occidental College',
#  'University of Cincinnati',
#  'Washington &amp; Jefferson College|Washington and Jefferson College',
#  'Master of Divinity|MDiv',
#  'Attorney General of Missouri',
#  'United States Senator',
#  'United States Ambassador to the United Nations',
#  'Episcopal priest',
#  'William H. Danforth',
#  'Ralston Purina',
#  'William Henry Danforth',
#  'Washington University in St. Louis',
#  'Mary Institute and St. Louis Country Day School|St. Louis Country Day School',
#  'Davis Polk &amp; Wardwell',
#  'List of United States Senators from Missouri|U.S. Senators',
#  'List of Governors of Missouri|Governors',
#  'Thomas Hart Benton (senator)|Thomas Hart Benton',
#  'Harry S. Truman',
#  'Missouri Attorney General',
#  'Kit Bond',
#  'John Ashcroft',
#  'Clarence Thomas',
#  'United States Senate',
#  'Stuart Symington',
#  'James W. Symington',
#  'Warren Hearnes',
#  'Jerry Litton',
#  'Jimmy Carter',
#  'Georgia (U.S. state)|Georgia',
#  'Inner Temple',
#  'Barrister-at-Law',
#  'Birkbeck College',
#  'Psychology',
#  'Ph.D.',
#  'Social psychology',
#  'D.Sc.',
#  'Edinburgh University',
#  'Royal College of Physicians of Edinburgh',
#  'Indiana University',
#  'Bachelor of arts|BA',
#  'Master of arts|MA',
#  'Marquette University',
#  'MIT',
#  'Colorado College',
#  'Williams College',
#  'Bowdoin College',
#  'Andover Theological Seminary',
#  'pedagogical',
#  'Jacob Abbott',
#  'Puritan|Congregational Church',
#  'Massachusetts',
#  'Napoleon Bonaparte',
#  'American Civil War|Civil War',
#  'Napoleon III',
#  'Frederick the Great',
#  'Daniel Boone',
#  'College of DuPage',
#  'American University',
#  'George Washington University|George Washington U.',
#  'Doctor of Medicine|MD',
#  'Smith College',
#  'Le Cordon Bleu',
#  'Morgan State University',
#  'Morris Brown College',
#  'Harvard Law School',
#  'University of Tokyo',
#  'University of Sofia',
#  'Deutsches Wörterbuch',
#  'Deutsche Mythologie',
#  'Brothers Grimm',
#  'Catholic University of America',
#  'London School of Hygiene &amp; Tropical Medicine',
#  'Georgia State University',
#  'Ludwig Maximilian University of Munich|University of Munich',
#  'Juilliard School',
#  'Northwestern University School of Law|Union College of Law',
#  'read law',
#  's Girls',
#  'Kwame Nkrumah University of Science and Technology|Kumasi College of Science and Technology',
#  'Macalester College',
#  'Graduate Institute of International and Development Studies',
#  'University of Tennessee',
#  'University of Karlsruhe',
#  'Charles University in Prague|Prague University',
#  'Buena Park High School',
#  'Diplomatic Academy of Vienna|Vienna Consular Academy',
#  'New Trier High School',
#  'Chuo University',
#  'Waseda University',
#  'Imperial University of Dorpat',
#  'University of Bristol',
#  'Munich Academy',
#  'Kyoto Imperial University',
#  'Gordon College (Massachusetts)|Gordon College',
#  'Aston University',
#  'National Ballet School|National Ballet School of Canada',
#  'Seattle Pacific University',
#  'UC Berkeley',
#  'Southern Methodist University',
#  'Berlin Institute of Technology|Technische Hochschule Berlin',
#  'diploma',
#  'Victoria University of Manchester',
#  'MPhil',
#  'National Film School of Denmark',
#  'Séminaire de Sherbrooke|Séminaire Saint-Charles-Borromée',
#  'Université Laval',
#  'Washburn University',
#  'Manumit School',
#  'St. Leo University|St. Leo College Preparatory School',
#  'Cheltenham College',
#  'University of Guelph',
#  'The Evergreen State College',
#  'Bachelor of Laws|LL.B.',
#  'University of Berlin|Friedrich Wilhelm University',
#  'Heidelberg University',
#  'Hunan First Normal University',
#  'University of Manitoba',
#  'London Film School',
#  'Barnard College',
#  'Architectural Association School of Architecture',
#  'Karlsruhe Institute of Technology|Technische Hochschule',
#  'University of Budapest',
#  'Tudor House School',
#  'Melbourne Grammar School',
#  'University of Hamburg',
#  'Plymouth College',
#  'Leighton Park School',
#  ' School|{{Longitem|Kesteven and Grantham Girls',
#  'Inns of Court School of Law',
#  'Lewis &amp; Clark College|Lewis and Clark College',
#  'Master of Science|MSc',
#  'Morehouse College',
#  'Crozer Theological Seminary',
#  'Bachelor of Divinity|BDiv',
#  'Boston University',
#  'Delft University of Technology|Technical College of Delft',
#  'Villa Welgelegen|Haarlem School of Architecture and Decorative Arts',
#  'Bristol Old Vic Theatre School',
#  'Brooklyn College',
#  'BSc',
#  's School (Baramulla)|St. Joseph',
#  'Baramulla',
#  'India',
#  'Pennsylvania Academy of the Fine Arts',
#  'Jean-Léon Gérôme',
#  'Charles Joshua Chaplin|Charles Chaplin',
#  'Thomas Couture',
#  'Gakushuin University',
#  'St. Bonaventure University',
#  'Bachelor of Science|B.Sc.',
#  'Cairo University',
#  'Hamburg University of Technology',
#  'The American University in Cairo',
#  'City Law School|Inns of Court School of Law',
#  'Manchester Grammar School',
#  'Peking University',
#  'Harvard Medical School',
#  'University of Warsaw',
#  'Wharton School of the University of Pennsylvania|University of Pennsylvania',
#  'Immaculate Heart High School (Los Angeles)|Immaculate Heart High School',
#  'Bradley University',
#  'Southern Illinois University Carbondale',
#  'juris doctor|J.D.',
#  'Metairie Park Country Day School',
#  'Mason College',
#  'University of Münster',
#  'Graz University of Technology',
#  'Harvard Society of Fellows',
#  'Yale College|Yale University',
#  'University of Adelaide',
#  'Cardiff University',
#  'University of Denver',
#  'Imperial Moscow University',
#  'Seichō-ji|Kiyozumi-dera',
#  'School of the Art Institute of Chicago',
#  'University of Halle',
#  'Portora Royal School',
#  'Stuyvesant High School',
#  'Keio University',
#  'Washington State University',
#  'Law',
#  'History',
#  'Philosophy',
#  'BPhil',
#  'New School',
#  'Master of Public Administration|MPA',
#  'Goethe University Frankfurt|University of Frankfurt',
#  'Padua University',
#  'Noble and Greenough School',
#  'Forman Christian College',
#  'Pakistan Military Academy',
#  'Command and Staff College',
#  'Royal College of Defence Studies|Royal College of Defence',
#  'EFREI',
#  'Université de Montréal',
#  'Sciences Po',
#  'Doctor of Law|LL.B.',
#  'Political economy',
#  'Sciences Po|Paris Institute of Political Studies',
#  'USNA',
#  'Marshall University',
#  'Eureka College',
#  'Whittier College',
#  'Duke University School of Law',
#  'West Hartlepool College of Art',
#  'Royal College of Art',
#  'Bachelor of Science|S.B. 1939',
#  'Doctor of Philosophy|Ph.D. 1942',
#  'Prytanée National Militaire|Collège Royal Henry-Le-Grand',
#  'University of Faraz',
#  'St. Anthony Catholic School',
#  'University of Texas at Austin College of Communication|College of Communication',
#  'University of Missouri',
#  's University at Kingston|Queen',
#  'Dalhousie University',
#  'Grinnell College',
#  'Oundle School',
#  'University of Rochester',
#  'Manhattan College',
#  'Politecnico di Milano',
#  'University of British Columbia',
#  'Banaras Hindu University',
#  'TU Wien|Vienna Institute of Technology',
#  'University of Rostock',
#  'Los Angeles High School',
#  'Bachelor of Divinity|BD',
#  'Doctor of Divinity|DD',
#  'Harvard Divinity School',
#  'Qom Seminary',
#  'Tokyo National University of Fine Arts and Music',
#  'Oxford University',
#  'Fulbright Program|Fulbright Scholar',
#  'Vanderbilt University',
#  'University of California at Berkeley',
#  'ETH Zurich',
#  'Edinburgh Academy',
#  'Isleworth',
#  'Lazarev Institute of Oriental Languages',
#  'Moscow University',
#  'New School of Social Research',
#  'Doctor of medicine|MD',
#  'Saratoga High School (California)|Saratoga High School',
#  'University of Maine',
#  'Hartwick College',
#  'University of Louisville',
#  'Huntingdon Grammar School',
#  'Lemelson Foundation',
#  'De Anza College',
#  'University of Colorado Boulder',
#  'Antioch College',
#  'University of Leeds',
#  'École royale du génie de Mézières|École Royale du Génie',
#  'Collège de France',
#  'Wellesley College',
#  'University of Manchester',
#  'University of Ballarat',
#  'Lviv Polytechnic|Technical University of Lwów',
#  'Stanford Graduate School of Business',
#  'University of Cambridge|Cambridge',
#  'College of William &amp; Mary|College of William and Mary',
#  'Charing Cross Hospital',
#  'Loyola University Maryland|Loyola College',
#  'Doctoral candidate|PhD (cand)',
#  'Pocklington School',
#  'Rensselaer Polytechnic Institute',
#  'South Dakota State University',
#  'University of Sussex',
#  'Wabash College',
#  'Taras Shevchenko National University of Kyiv',
#  'Hamilton College',
#  'Washington and Lee University',
#  'Juris Doctor|J.D.',
#  'California Institute of the Arts',
#  'University of Kentucky',
#  'Swarthmore College',
#  'Radcliffe College',
#  'Collège Louis-le-Grand',
#  'Saint Petersburg Imperial University',
#  'Doctor of Science',
#  'University of Kazan',
#  'Polytechnic University of Turin|Technical School for Engineers in Turin',
#  'Davidson College',
#  'University of Arkansas',
#  'Tufts College',
#  'B.S.',
#  'M.S.',
#  'D.Eng.',
#  'Woldingham School|Convent of the Sacred Heart',
#  'LLB',
#  'Saint Petersburg Mining Institute',
#  'Candidate of Sciences|PhD',
#  'Universidad Iberoamericana',
#  'Ohio Central College',
#  'Viadrina European University|University of Frankfurt (Oder)',
#  'Caltech',
#  'Whitman College',
#  'Hampden–Sydney College',
#  'Royal Belfast Academical Institution',
#  'Glasgow University',
#  'Bachelor of Civil Law|LL.L.',
#  'Osgoode Hall Law School',
#  'Allegheny College',
#  'Mount Union College',
#  'Albany Law School',
#  'Harvard College|Harvard University',
#  'Utrecht University',
#  'Jan H. Hofmeyr School of Social Work',
#  'University of the Witwatersrand',
#  'Nyenrode Business University',
#  'Bachelor of Public Administration|BPA',
#  'Friedrich Wilhelms University of Berlin',
#  'Abeokuta Grammar School',
#  'Oberlin College',
#  'Ludwig-Maximilians University',
#  'NYU',
#  'Political Science',
#  'Montclair State University',
#  'Social Sciences',
#  'Fordham University Law School',
#  'Mount Saint Dominic Academy',
#  'Howard University',
#  'Hamburg University of Applied Sciences',
#  'Stockholm University',
#  'Air Force Institute of Technology',
#  'United States Military Academy|USMA',
#  'University of Michigan|UMich',
#  'Illinois Institute of Technology',
#  'Virginia Military Institute',
#  'San Jose State University',
#  'Charles University',
#  'Academy of Performing Arts in Prague',
#  'King Edward VI High School for Girls|King Edward VI High School',
#  'UCL Medical School',
#  'Miami University',
#  'Stefan Batory University',
#  'University of California at Los Angeles',
#  'University of Genoa',
#  'Lick-Wilmerding High School',
#  'RWTH Aachen',
#  'Norwegian University of Science and Technology',
#  'Hampton Normal and Agricultural Institute',
#  'Wayland Seminary',
#  'Royal Danish Academy of Fine Arts',
#  'Tak Sun Secondary School|Tak Sun',
#  'La Salle College',
#  'Seattle Central College|Edison Technical School',
#  'Western Reserve University',
#  'College of Navarre',
#  'University of York',
#  'Northeastern University',
#  'University of Illinois at Urbana–Champaign',
#  'École normale supérieure (Paris)|École Normale Supérieure',
#  'Humboldt University of Berlin|Friedrich Wilhelms University',
#  'Poznań University of Technology',
#  'University of Havana',
#  'University of Debrecen',
#  'Tufts University',
#  'Yale Law School|Yale University',
#  'New York University School of Law|New York University',
#  'LLM',
#  'Harvard Business School',
#  'University of South Dakota',
#  'University of Baltimore',
#  'Uppsala University|University of Uppsala',
#  'New College of Florida',
#  'female impersonator',
#  'Bette Davis',
#  'tuxedo (clothing)|tuxedo',
#  'drag queen',
#  'San Francisco',
#  'Hollywood',
#  'Mae West',
#  'Tallulah Bankhead',
#  'Gloria Swanson',
#  'Carol Channing',
#  'Katharine Hepburn',
#  'Joan Crawford',
#  'Canon (basic principle)|canon',
#  'Imitation|mimicry',
#  'Joan Collins',
#  'celebrities',
#  'Studio One Backlot',
#  'Kirk Frederick',
#  'Geraldine Fitzgerald',
#  'Nightclub|clubs',
#  'The Village Gate',
#  'Fairmont San Francisco#Popular culture|Venetian Room',
#  'Fairmont San Francisco|Fairmont Hotel',
#  'Louise M. Davies Symphony Hall',
#  'War Memorial Opera House',
#  'Wonder Woman (TV series)|Wonder Woman',
#  'cross-dressing',
#  'Laverne &amp; Shirley',
#  'Dixie Carter',
#  'sitcom',
#  'Designing Women',
#  'cruise ship',
#  'Forest Lawn Memorial Park (Hollywood Hills)|Forest Lawn Memorial Park',
#  'Bea Arthur',
#  'Forest Lawn Memorial Park (Hollywood Hills)|Forest Lawn - Hollywood Hills Cemetery',
#  'Tony Award',
#  'Sapienza University of Rome|University of Rome',
#  'Leibniz University Hannover|Hannover Polytechnic',
#  'Kunstakademie Düsseldorf',
#  'Larchfield Academy',
#  'Royal Technical College',
#  'University of Strathclyde',
#  'Oxford University|Oxford',
#  'University of Bern',
#  'Latymer Upper School',
#  'Chelsea College of Art and Design',
#  'Fiorello H. LaGuardia High School',
#  'DePaul University',
#  'Mayor of Chicago',
#  'Cook County Democratic Party',
#  'Irish American',
#  'Daley family',
#  'Richard M. Daley',
#  'William M. Daley',
#  'United States Secretary of Commerce',
#  'John P. Daley',
#  'Cook County Board of Commissioners',
#  'Patrick Daley Thompson',
#  'Chicago City Council',
#  'rust belt',
#  'Cleveland',
#  'Detroit',
#  'Irish Catholic',
#  'Lyndon B. Johnson',
#  'Kennedy family',
#  'history of the United States Democratic Party',
#  'John F. Kennedy',
#  '1960 United States presidential election|1960',
#  'Hubert Humphrey',
#  '1968 United States presidential election|1968',
#  'Martin Luther King Jr.',
#  '1968 Democratic National Convention',
#  'political corruption|corruption',
#  'New York University Law School',
#  'St. Mary of the Woods College|St. Mary of the Woods',
#  'Barat College',
#  'Roosevelt University',
#  'Hiram College',
#  'Lombard College',
#  'Jesuit',
#  'Lyceum',
#  'Baron',
#  'Slovenes|Slovene',
#  'mathematician',
#  'physicist',
#  'artillery',
#  'Commissioned officer|officer',
#  'Founding Fathers of the United States',
#  'U.S. Constitution',
#  'Federalist Party',
#  'United States Coast Guard',
#  'New York Post',
#  'Secretary of the Treasury',
#  'George Washington',
#  'First Bank of the United States|national bank',
#  'Nevis',
#  'American Revolutionary War',
#  'Continental Army',
#  'Congress of the Confederation',
#  'Bank of New York',
#  'Articles of Confederation',
#  'Annapolis Convention (1786)|Annapolis Convention of 1786',
#  'Constitutional Convention (United States)|Constitutional Convention',
#  'Philadelphia',
#  'The Federalist Papers',
#  'Constitutional interpretation',
#  'United States Department of the Treasury|Treasury Department',
#  'implied powers',
#  'National debt of the United States|national debt',
#  'tariff',
#  'whiskey tax',
#  'French Revolution|French revolutionaries',
#  'Democratic-Republican Party (United States)|Democratic-Republican Party',
#  'Thomas Jefferson',
#  'James Madison',
#  'French First Republic',
#  'John Adams',
#  'Commanding General of the United States Army|Commanding General',
#  'Quasi-War',
#  '1800 United States presidential election|1800',
#  'Aaron Burr',
#  'United States electoral college|electoral college',
#  'Burr–Hamilton duel|a duel',
#  'Illinois College',
#  'Lviv Polytechnic#Second Polish Republic|Lwów Polytechnic Institute',
#  'Second Polish Republic',
#  'Rheinische Friedrich-Wilhelms-Universität Bonn',
#  'Goethe University Frankfurt',
#  'PhD|Ph.D.',
#  'HB Studio',
#  'Neue Deutsche Biographie',
#  'West Thames College|Isleworth Polytechnic College',
#  'Ealing Art College',
#  'Hampton School|Hampton Grammar School',
#  'Doctor of Philosophy|Ph.D',
#  'Leiden University|University of Leiden',
#  'University of Angers',
#  'C.B.S. Charleville',
#  'Blackrock College',
#  'Royal University of Ireland',
#  'Saint Petersburg State Electrotechnical University',
#  'Eötvös Loránd University|University of Budapest',
#  'Wesleyan University',
#  'Industrial Academy (Moscow)|Industrial Academy',
#  'Colegio Militar de la Nación',
#  'Louisiana State University',
#  'Delft University of Technology',
#  'University of Utrecht',
#  'Manhattanville College',
#  'University of Illinois at Chicago',
#  'Princeton Theological Seminary',
#  'Master of Divinity|M.Div.',
#  ...]

# %%
# the number of people that attended each college
college_count = []
# an array with the names of each person that attended the college (so we can reference the other DataFrame)
college_students = []
for college in colleges:
    college_count.append(0)
    college_students.append([])

# %% [markdown]
# #### Construct the Dataframe

# %%
tertiary_education = pandas.DataFrame({'school':colleges,'count':college_count,'notable_students':college_students})
tertiary_education = tertiary_education.set_index('school')
tertiary_education.head()
# Out:
#                                        count notable_students
# school
# École Normale Supérieure                   0               []
# Pierre and Marie Curie University          0               []
# Eton College                               0               []
# ETH Zurich|Federal Polytechnic School      0               []
# Zurich                                     0               []

# %% [markdown]
# Let's fill her up with data.

# %%
# testing index function
print (college_count[colleges.index('Cornell University')])
colleges.index('Cornell University')
# Out:
# 0
# 133

# %%
for index in wikipeople.index:
    for school in wikipeople['education'][index]:
        college_count[colleges.index(school)] += 1
        college_students[colleges.index(school)].append(index)

# %%
# testing count
print (college_count[colleges.index('Cornell University')])
colleges.index('Cornell University')
# Out:
# 1759
# 133

# %% [markdown]
# We've had 1759 wikipedia-level famous people attend Cornell! I wonder if this is a lot or a little in comparison to other schools.

# %%
tertiary_education = pandas.DataFrame({'school':colleges,'count':college_count,'notable_students':college_students})
tertiary_education = tertiary_education.set_index('school')
tertiary_education.head()
# Out:
#                                        count  \
# school
# École Normale Supérieure                 199
# Pierre and Marie Curie University         48
# Eton College                             702
# ETH Zurich|Federal Polytechnic School      1
# Zurich                                    15
#
#                                                                         notable_students
# school
# École Normale Supérieure               [Alain Connes, André Weil, Henri Bergson, Jean...
# Pierre and Marie Curie University      [Alain Connes, Ahmad Motamedi, Pierre-Louis Li...
# Eton College                           [Aldous Huxley, A. J. Ayer, George Orwell, Hor...
# ETH Zurich|Federal Polytechnic School                                  [Albert Einstein]
# Zurich                                 [Albert Einstein, Claus Westermann, Annemarie ...

# %% [markdown]
# The really cool part is that now to access the rest of the data, we just need to use an element of the `notable_students` array as the index of the wikipeople dataframe to get their birth_date, occupation, or other schools.

# %% [markdown]
# #### Save dataframes

# %% [markdown]
# Let's save the work we've done so we can load it up in other notebooks.

# %%
wikipeople.head()
# Out:
#                      birth_date                     occupation  \
# name
# Alain Connes               1947                            nan
# Aldous Huxley              1894   {{hlist|writer|philosopher}}
# Arthur Schopenhauer        1788                            nan
# Albert Einstein            1879                            nan
# Alfred Korzybski           1879                            nan
#
#                                                              education
# name
# Alain Connes         [École Normale Supérieure, Pierre and Marie Cu...
# Aldous Huxley                                           [Eton College]
# Arthur Schopenhauer                                                 []
# Albert Einstein      [ETH Zurich|Federal Polytechnic School, Zurich...
# Alfred Korzybski                     [Warsaw University of Technology]

# %%
tertiary_education.head()
# Out:
#                                        count  \
# school
# École Normale Supérieure                 199
# Pierre and Marie Curie University         48
# Eton College                             702
# ETH Zurich|Federal Polytechnic School      1
# Zurich                                    15
#
#                                                                         notable_students
# school
# École Normale Supérieure               [Alain Connes, André Weil, Henri Bergson, Jean...
# Pierre and Marie Curie University      [Alain Connes, Ahmad Motamedi, Pierre-Louis Li...
# Eton College                           [Aldous Huxley, A. J. Ayer, George Orwell, Hor...
# ETH Zurich|Federal Polytechnic School                                  [Albert Einstein]
# Zurich                                 [Albert Einstein, Claus Westermann, Annemarie ...

# %%
wikipeople.to_csv('wikipeople_cleaned.csv',index=True)

# %%
tertiary_education.to_csv('tertiary_education.csv',index=True)

# %% [markdown]
# That's all, folks! We now have data in two very neat DataFrames. Next up: we do some analysis with this well-formatted data tables!
